# %%
import numpy as np
import aniposelib
import toml
import pandas as pd
from aniposelib.boards import CharucoBoard, Checkerboard
from aniposelib.cameras import Camera, CameraGroup
from aniposelib.utils import load_pose2d_fnames

import os

# %%
# calibrate the cameras for 3d

do_cali = 0

#vidnames = [['camera-1_new_position_20221107.mp4'],
#            ['camera-2_new_position_20221107.mp4'],
#            ['camera-3_new_position_20221107.mp4']]
vidnames = [['camera-1_new_position_20221109_merge.mp4'],
            ['camera-2_new_position_20221109_merge.mp4'],
            ['camera-3_new_position_20221109_merge.mp4']]

cam_names = ['1', '2', '3']

n_cams = len(vidnames)

board = Checkerboard(8, 6,
                     square_length=1, # here, in mm but any unit works
                     manually_verify=False)


# the videos provided are fisheye, so we need the fisheye option
cgroup = CameraGroup.from_names(cam_names, fisheye=False)

# %%
if do_cali: 
    # this will take about 15 minutes (mostly due to detection)
    # it will detect the charuco board in the videos,
    # then calibrate the cameras based on the detections, using iterative bundle adjustment
    cgroup.calibrate_videos(vidnames, board)

    # if you need to save and load
    # example saving and loading for later
    cgroup.dump('calibration.toml')

# %%
if not do_cali:
    ## example of loading calibration from a file
    ## you can also load the provided file if you don't want to wait 15 minutes
    cgroup = CameraGroup.load('calibration.toml')

# %%
lever_locs_all = {'camera-1':{('dodson'):np.array([645, 600]),('scorch'):np.array([425, 435])},
                  'camera-2':{('dodson'):np.array([1335,715]),('scorch'):np.array([550, 715])},
                  'camera-3':{('dodson'):np.array([1580,440]),('scorch'):np.array([1296,540])}}
tube_locs_all = {'camera-1':{('dodson'):np.array([1350,630]),('scorch'):np.array([555, 345])},
                 'camera-2':{('dodson'):np.array([1550,515]),('scorch'):np.array([350, 515])},
                 'camera-3':{('dodson'):np.array([1470,375]),('scorch'):np.array([805,475])}}
boxCorner1_locs_all = {'camera-1':{('dodson'):np.array([673, 421]),('scorch'):np.array([659, 408])},
                       'camera-2':{('dodson'):np.array([936, 527]),('scorch'):np.array([902, 526])},
                       'camera-3':{('dodson'):np.array([1323,395]),('scorch'):np.array([1310,398])}}
boxCorner2_locs_all = {'camera-1':{('dodson'):np.array([700, 682]),('scorch'):np.array([679, 665])},
                       'camera-2':{('dodson'):np.array([951, 773]),('scorch'):np.array([912, 775])},
                       'camera-3':{('dodson'):np.array([1285,634]),('scorch'):np.array([1270,641])}}
boxCorner3_locs_all = {'camera-1':{('dodson'):np.array([1232,1070]),('scorch'):np.array([501,513])},
                       'camera-2':{('dodson'):np.array([1599, 748]),('scorch'):np.array([236,791])},
                       'camera-3':{('dodson'):np.array([1525, 528]),('scorch'):np.array([734,864])}}
boxCorner4_locs_all = {'camera-1':{('dodson'):np.array([1585, 698]),('scorch'):np.array([842,446])},
                       'camera-2':{('dodson'):np.array([1343, 424]),('scorch'):np.array([502,461])},
                       'camera-3':{('dodson'):np.array([1190, 426]),('scorch'):np.array([511,581])}}

# %%
## example triangulation without filtering, should take < 15 seconds
date_tgt = '20221128'
animal1 = 'Eddie'
animal2 = 'Sparkle'
singlecam_ana_type = "DLC_dlcrnetms5_marmoset_tracking_with_middle_cameraSep1shuffle1_150000"

current_dir = os.getcwd()
add_date_dir = current_dir+'/anipose_3d_h5_files/'+date_tgt+'_'+animal1+'_'+animal2
bodyparts_3d_anipose_file = add_date_dir+'/'+date_tgt+'_'+animal1+'_'+animal2+'_anipose.h5'
if os.path.exists(bodyparts_3d_anipose_file):
    do_3dconstruct = 0
else:
    do_3dconstruct = 1
# do_3dconstruct=1
    
if do_3dconstruct:   

    twocamera_videos_cam12 = "/gpfs/gibbs/pi/jadi/VideoTracker_SocialInter/test_video_cooperative_task_3d/"+date_tgt+"_"+animal1+"_"+animal2+"_camera12/"
    twocamera_videos_cam23 = "/gpfs/gibbs/pi/jadi/VideoTracker_SocialInter/test_video_cooperative_task_3d/"+date_tgt+"_"+animal1+"_"+animal2+"_camera23/"

    bodyparts_cam1_cam12 = twocamera_videos_cam12+date_tgt+"_"+animal1+"_"+animal2+"_camera-1"+singlecam_ana_type+"_el_filtered.h5"
    bodyparts_cam2_cam12 = twocamera_videos_cam12+date_tgt+"_"+animal1+"_"+animal2+"_camera-2"+singlecam_ana_type+"_el_filtered.h5"
    bodyparts_cam3_cam23 = twocamera_videos_cam23+date_tgt+"_"+animal1+"_"+animal2+"_camera-3"+singlecam_ana_type+"_el_filtered.h5"

    bodyparts_3d_cam12_DLC = twocamera_videos_cam12+date_tgt+"_"+animal1+"_"+animal2+"_weikang.h5"
    bodyparts_3d_cam23_DLC = twocamera_videos_cam23+date_tgt+"_"+animal1+"_"+animal2+"_weikang.h5"


    ## save the the h5 file separately for each animals and save them in the same folder for future purpose

    # animal 1 - "dodson"

    # dodson h5 files
    bodyparts_cam1_cam12_dodson = twocamera_videos_cam12+date_tgt+"_"+animal1+"_"+animal2+"_camera-1"+singlecam_ana_type+"_el_filtered_dodson.h5"
    bodyparts_cam2_cam12_dodson = twocamera_videos_cam12+date_tgt+"_"+animal1+"_"+animal2+"_camera-2"+singlecam_ana_type+"_el_filtered_dodson.h5"
    bodyparts_cam3_cam23_dodson = twocamera_videos_cam23+date_tgt+"_"+animal1+"_"+animal2+"_camera-3"+singlecam_ana_type+"_el_filtered_dodson.h5"

    # cam1 dodson
    bodyparts_cam1_cam12_data = pd.read_hdf(bodyparts_cam1_cam12)
    bodyparts_cam1_cam12_dodson_data = {}
    bodyparts_cam1_cam12_dodson_data[singlecam_ana_type]=bodyparts_cam1_cam12_data.loc[:,(singlecam_ana_type,'dodson')]
    bodyparts_cam1_cam12_dodson_data=pd.concat(bodyparts_cam1_cam12_dodson_data, axis=1)
    # add lever
    lever_x = np.ones((1,np.shape(bodyparts_cam1_cam12_dodson_data)[0]))*lever_locs_all['camera-1']['dodson'][0]
    lever_y = np.ones((1,np.shape(bodyparts_cam1_cam12_dodson_data)[0]))*lever_locs_all['camera-1']['dodson'][1]
    lever_likelihood = np.ones((1,np.shape(bodyparts_cam1_cam12_dodson_data)[0]))
    bodyparts_cam1_cam12_dodson_data[(singlecam_ana_type,'lever','x')]=lever_x[0]
    bodyparts_cam1_cam12_dodson_data[(singlecam_ana_type,'lever','y')]=lever_y[0]
    bodyparts_cam1_cam12_dodson_data[(singlecam_ana_type,'lever','likelihood')]=lever_likelihood[0]
    # add tube
    tube_x = np.ones((1,np.shape(bodyparts_cam1_cam12_dodson_data)[0]))*tube_locs_all['camera-1']['dodson'][0]
    tube_y = np.ones((1,np.shape(bodyparts_cam1_cam12_dodson_data)[0]))*tube_locs_all['camera-1']['dodson'][1]
    tube_likelihood = np.ones((1,np.shape(bodyparts_cam1_cam12_dodson_data)[0]))
    bodyparts_cam1_cam12_dodson_data[(singlecam_ana_type,'tube','x')]=tube_x[0]
    bodyparts_cam1_cam12_dodson_data[(singlecam_ana_type,'tube','y')]=tube_y[0]
    bodyparts_cam1_cam12_dodson_data[(singlecam_ana_type,'tube','likelihood')]=tube_likelihood[0]
    #
    bodyparts_cam1_cam12_dodson_data.to_hdf(bodyparts_cam1_cam12_dodson,key='tracks')

    # cam2 dodson
    bodyparts_cam2_cam12_data = pd.read_hdf(bodyparts_cam2_cam12)
    bodyparts_cam2_cam12_dodson_data = {}
    bodyparts_cam2_cam12_dodson_data[singlecam_ana_type]=bodyparts_cam2_cam12_data.loc[:,(singlecam_ana_type,'dodson')]
    bodyparts_cam2_cam12_dodson_data=pd.concat(bodyparts_cam2_cam12_dodson_data, axis=1)
    # add lever
    lever_x = np.ones((1,np.shape(bodyparts_cam2_cam12_dodson_data)[0]))*lever_locs_all['camera-2']['dodson'][0]
    lever_y = np.ones((1,np.shape(bodyparts_cam2_cam12_dodson_data)[0]))*lever_locs_all['camera-2']['dodson'][1]
    lever_likelihood = np.ones((1,np.shape(bodyparts_cam2_cam12_dodson_data)[0]))
    bodyparts_cam2_cam12_dodson_data[(singlecam_ana_type,'lever','x')]=lever_x[0]
    bodyparts_cam2_cam12_dodson_data[(singlecam_ana_type,'lever','y')]=lever_y[0]
    bodyparts_cam2_cam12_dodson_data[(singlecam_ana_type,'lever','likelihood')]=lever_likelihood[0]
    # add tube
    tube_x = np.ones((1,np.shape(bodyparts_cam2_cam12_dodson_data)[0]))*tube_locs_all['camera-2']['dodson'][0]
    tube_y = np.ones((1,np.shape(bodyparts_cam2_cam12_dodson_data)[0]))*tube_locs_all['camera-2']['dodson'][1]
    tube_likelihood = np.ones((1,np.shape(bodyparts_cam2_cam12_dodson_data)[0]))
    bodyparts_cam2_cam12_dodson_data[(singlecam_ana_type,'tube','x')]=tube_x[0]
    bodyparts_cam2_cam12_dodson_data[(singlecam_ana_type,'tube','y')]=tube_y[0]
    bodyparts_cam2_cam12_dodson_data[(singlecam_ana_type,'tube','likelihood')]=tube_likelihood[0]
    #
    bodyparts_cam2_cam12_dodson_data.to_hdf(bodyparts_cam2_cam12_dodson,key='tracks')

    # cam3 dodson
    bodyparts_cam3_cam23_data = pd.read_hdf(bodyparts_cam3_cam23)
    bodyparts_cam3_cam23_dodson_data = {}
    bodyparts_cam3_cam23_dodson_data[singlecam_ana_type]=bodyparts_cam3_cam23_data.loc[:,(singlecam_ana_type,'dodson')]
    bodyparts_cam3_cam23_dodson_data=pd.concat(bodyparts_cam3_cam23_dodson_data, axis=1)
    # add lever
    lever_x = np.ones((1,np.shape(bodyparts_cam3_cam23_dodson_data)[0]))*lever_locs_all['camera-3']['dodson'][0]
    lever_y = np.ones((1,np.shape(bodyparts_cam3_cam23_dodson_data)[0]))*lever_locs_all['camera-3']['dodson'][1]
    lever_likelihood = np.ones((1,np.shape(bodyparts_cam3_cam23_dodson_data)[0]))
    bodyparts_cam3_cam23_dodson_data[(singlecam_ana_type,'lever','x')]=lever_x[0]
    bodyparts_cam3_cam23_dodson_data[(singlecam_ana_type,'lever','y')]=lever_y[0]
    bodyparts_cam3_cam23_dodson_data[(singlecam_ana_type,'lever','likelihood')]=lever_likelihood[0]
    # add tube
    tube_x = np.ones((1,np.shape(bodyparts_cam3_cam23_dodson_data)[0]))*tube_locs_all['camera-3']['dodson'][0]
    tube_y = np.ones((1,np.shape(bodyparts_cam3_cam23_dodson_data)[0]))*tube_locs_all['camera-3']['dodson'][1]
    tube_likelihood = np.ones((1,np.shape(bodyparts_cam3_cam23_dodson_data)[0]))
    bodyparts_cam3_cam23_dodson_data[(singlecam_ana_type,'tube','x')]=tube_x[0]
    bodyparts_cam3_cam23_dodson_data[(singlecam_ana_type,'tube','y')]=tube_y[0]
    bodyparts_cam3_cam23_dodson_data[(singlecam_ana_type,'tube','likelihood')]=tube_likelihood[0]
    #
    bodyparts_cam3_cam23_dodson_data.to_hdf(bodyparts_cam3_cam23_dodson,key='tracks')


    # animal 2 - "scorch"

    # scorch h5 files
    bodyparts_cam1_cam12_scorch = twocamera_videos_cam12+date_tgt+"_"+animal1+"_"+animal2+"_camera-1"+singlecam_ana_type+"_el_filtered_scorch.h5"
    bodyparts_cam2_cam12_scorch = twocamera_videos_cam12+date_tgt+"_"+animal1+"_"+animal2+"_camera-2"+singlecam_ana_type+"_el_filtered_scorch.h5"
    bodyparts_cam3_cam23_scorch = twocamera_videos_cam23+date_tgt+"_"+animal1+"_"+animal2+"_camera-3"+singlecam_ana_type+"_el_filtered_scorch.h5"

    # cam1 scorch
    bodyparts_cam1_cam12_data = pd.read_hdf(bodyparts_cam1_cam12)
    bodyparts_cam1_cam12_scorch_data = {}
    bodyparts_cam1_cam12_scorch_data[singlecam_ana_type]=bodyparts_cam1_cam12_data.loc[:,(singlecam_ana_type,'scorch')]
    bodyparts_cam1_cam12_scorch_data=pd.concat(bodyparts_cam1_cam12_scorch_data, axis=1)
    # add lever
    lever_x = np.ones((1,np.shape(bodyparts_cam1_cam12_scorch_data)[0]))*lever_locs_all['camera-1']['scorch'][0]
    lever_y = np.ones((1,np.shape(bodyparts_cam1_cam12_scorch_data)[0]))*lever_locs_all['camera-1']['scorch'][1]
    lever_likelihood = np.ones((1,np.shape(bodyparts_cam1_cam12_scorch_data)[0]))
    bodyparts_cam1_cam12_scorch_data[(singlecam_ana_type,'lever','x')]=lever_x[0]
    bodyparts_cam1_cam12_scorch_data[(singlecam_ana_type,'lever','y')]=lever_y[0]
    bodyparts_cam1_cam12_scorch_data[(singlecam_ana_type,'lever','likelihood')]=lever_likelihood[0]
    # add tube
    tube_x = np.ones((1,np.shape(bodyparts_cam1_cam12_scorch_data)[0]))*tube_locs_all['camera-1']['scorch'][0]
    tube_y = np.ones((1,np.shape(bodyparts_cam1_cam12_scorch_data)[0]))*tube_locs_all['camera-1']['scorch'][1]
    tube_likelihood = np.ones((1,np.shape(bodyparts_cam1_cam12_scorch_data)[0]))
    bodyparts_cam1_cam12_scorch_data[(singlecam_ana_type,'tube','x')]=tube_x[0]
    bodyparts_cam1_cam12_scorch_data[(singlecam_ana_type,'tube','y')]=tube_y[0]
    bodyparts_cam1_cam12_scorch_data[(singlecam_ana_type,'tube','likelihood')]=tube_likelihood[0]
    #
    bodyparts_cam1_cam12_scorch_data.to_hdf(bodyparts_cam1_cam12_scorch,key='tracks')

    # cam2 scorch
    bodyparts_cam2_cam12_data = pd.read_hdf(bodyparts_cam2_cam12)
    bodyparts_cam2_cam12_scorch_data = {}
    bodyparts_cam2_cam12_scorch_data[singlecam_ana_type]=bodyparts_cam2_cam12_data.loc[:,(singlecam_ana_type,'scorch')]
    bodyparts_cam2_cam12_scorch_data=pd.concat(bodyparts_cam2_cam12_scorch_data, axis=1)
    # add lever
    lever_x = np.ones((1,np.shape(bodyparts_cam2_cam12_scorch_data)[0]))*lever_locs_all['camera-2']['scorch'][0]
    lever_y = np.ones((1,np.shape(bodyparts_cam2_cam12_scorch_data)[0]))*lever_locs_all['camera-2']['scorch'][1]
    lever_likelihood = np.ones((1,np.shape(bodyparts_cam2_cam12_scorch_data)[0]))
    bodyparts_cam2_cam12_scorch_data[(singlecam_ana_type,'lever','x')]=lever_x[0]
    bodyparts_cam2_cam12_scorch_data[(singlecam_ana_type,'lever','y')]=lever_y[0]
    bodyparts_cam2_cam12_scorch_data[(singlecam_ana_type,'lever','likelihood')]=lever_likelihood[0]
    # add tube
    tube_x = np.ones((1,np.shape(bodyparts_cam2_cam12_scorch_data)[0]))*tube_locs_all['camera-2']['scorch'][0]
    tube_y = np.ones((1,np.shape(bodyparts_cam2_cam12_scorch_data)[0]))*tube_locs_all['camera-2']['scorch'][1]
    tube_likelihood = np.ones((1,np.shape(bodyparts_cam2_cam12_scorch_data)[0]))
    bodyparts_cam2_cam12_scorch_data[(singlecam_ana_type,'tube','x')]=tube_x[0]
    bodyparts_cam2_cam12_scorch_data[(singlecam_ana_type,'tube','y')]=tube_y[0]
    bodyparts_cam2_cam12_scorch_data[(singlecam_ana_type,'tube','likelihood')]=tube_likelihood[0]
    #
    bodyparts_cam2_cam12_scorch_data.to_hdf(bodyparts_cam2_cam12_scorch,key='tracks')

    # cam3 scorch
    bodyparts_cam3_cam23_data = pd.read_hdf(bodyparts_cam3_cam23)
    bodyparts_cam3_cam23_scorch_data = {}
    bodyparts_cam3_cam23_scorch_data[singlecam_ana_type]=bodyparts_cam3_cam23_data.loc[:,(singlecam_ana_type,'scorch')]
    bodyparts_cam3_cam23_scorch_data=pd.concat(bodyparts_cam3_cam23_scorch_data, axis=1)
    # add lever
    lever_x = np.ones((1,np.shape(bodyparts_cam3_cam23_scorch_data)[0]))*lever_locs_all['camera-3']['scorch'][0]
    lever_y = np.ones((1,np.shape(bodyparts_cam3_cam23_scorch_data)[0]))*lever_locs_all['camera-3']['scorch'][1]
    lever_likelihood = np.ones((1,np.shape(bodyparts_cam3_cam23_scorch_data)[0]))
    bodyparts_cam3_cam23_scorch_data[(singlecam_ana_type,'lever','x')]=lever_x[0]
    bodyparts_cam3_cam23_scorch_data[(singlecam_ana_type,'lever','y')]=lever_y[0]
    bodyparts_cam3_cam23_scorch_data[(singlecam_ana_type,'lever','likelihood')]=lever_likelihood[0]
    # add tube
    tube_x = np.ones((1,np.shape(bodyparts_cam3_cam23_scorch_data)[0]))*tube_locs_all['camera-3']['scorch'][0]
    tube_y = np.ones((1,np.shape(bodyparts_cam3_cam23_scorch_data)[0]))*tube_locs_all['camera-3']['scorch'][1]
    tube_likelihood = np.ones((1,np.shape(bodyparts_cam3_cam23_scorch_data)[0]))
    bodyparts_cam3_cam23_scorch_data[(singlecam_ana_type,'tube','x')]=tube_x[0]
    bodyparts_cam3_cam23_scorch_data[(singlecam_ana_type,'tube','y')]=tube_y[0]
    bodyparts_cam3_cam23_scorch_data[(singlecam_ana_type,'tube','likelihood')]=tube_likelihood[0]
    #
    bodyparts_cam3_cam23_scorch_data.to_hdf(bodyparts_cam3_cam23_scorch,key='tracks')

# %%
## read the 3d recontruction h5 file
if do_3dconstruct:
    bodyparts_3d_cam12_DLC_data = pd.read_hdf(bodyparts_3d_cam12_DLC)
    bodyparts_3d_cam12_DLC_data.head()

# %%
## triangulation without filtering, should take < 15 seconds
if do_3dconstruct:
    # for the animal 1 - dodson
    fname_dict = {
        '1': bodyparts_cam1_cam12_dodson,
        '2': bodyparts_cam2_cam12_dodson,
        '3': bodyparts_cam3_cam23_dodson,
    }

    d = load_pose2d_fnames(fname_dict, cam_names=cgroup.get_names())

    score_threshold = 0.1

    n_cams, n_points, n_joints, _ = d['points'].shape
    points = d['points']
    scores = d['scores']

    bodyparts = d['bodyparts']

    # remove points that are below threshold
    points[scores < score_threshold] = np.nan

    points_flat = points.reshape(n_cams, -1, 2)
    scores_flat = scores.reshape(n_cams, -1)

    p3ds_flat = cgroup.triangulate(points_flat, progress=True)
    reprojerr_flat = cgroup.reprojection_error(p3ds_flat, points_flat, mean=True)

    p3ds = p3ds_flat.reshape(n_points, n_joints, 3)
    reprojerr = reprojerr_flat.reshape(n_points, n_joints)

# %%
## save the new files - animal 1 dodson
if do_3dconstruct:
    bodyparts_3d_dodson_anipose = {}
    nbodyparts = np.shape(bodyparts)[0]
    for ibodypart in np.arange(0,nbodyparts,1):
        # remove outlier
        ind_outlier_x = (p3ds[:,ibodypart,0]<(np.nanmean(p3ds[:,ibodypart,0])-2*np.nanstd(p3ds[:,ibodypart,0])))|(p3ds[:,ibodypart,0]>(np.nanmean(p3ds[:,ibodypart,0])+2*np.nanstd(p3ds[:,ibodypart,0])))
        p3ds[ind_outlier_x,ibodypart,0]=np.nan
        ind_outlier_y = (p3ds[:,ibodypart,1]<(np.nanmean(p3ds[:,ibodypart,1])-2*np.nanstd(p3ds[:,ibodypart,1])))|(p3ds[:,ibodypart,1]>(np.nanmean(p3ds[:,ibodypart,1])+2*np.nanstd(p3ds[:,ibodypart,1])))
        p3ds[ind_outlier_y,ibodypart,1]=np.nan
        ind_outlier_z = (p3ds[:,ibodypart,2]<(np.nanmean(p3ds[:,ibodypart,2])-2*np.nanstd(p3ds[:,ibodypart,2])))|(p3ds[:,ibodypart,2]>(np.nanmean(p3ds[:,ibodypart,2])+2*np.nanstd(p3ds[:,ibodypart,2])))
        p3ds[ind_outlier_z,ibodypart,2]=np.nan

        bodyparts_3d_dodson_anipose[('weikang','dodson',bodyparts[ibodypart],'x')] = p3ds[:,ibodypart, 0]
        bodyparts_3d_dodson_anipose[('weikang','dodson',bodyparts[ibodypart],'y')] = p3ds[:,ibodypart, 1]
        bodyparts_3d_dodson_anipose[('weikang','dodson',bodyparts[ibodypart],'z')] = p3ds[:,ibodypart, 2]
    bodyparts_3d_dodson_anipose = pd.DataFrame(bodyparts_3d_dodson_anipose)

# %%
## triangulation without filtering, should take < 15 seconds
if do_3dconstruct:
    # for the animal 1 - scorch
    fname_dict = {
        '1': bodyparts_cam1_cam12_scorch,
        '2': bodyparts_cam2_cam12_scorch,
        '3': bodyparts_cam3_cam23_scorch,
    }

    d = load_pose2d_fnames(fname_dict, cam_names=cgroup.get_names())

    score_threshold = 0.1

    n_cams, n_points, n_joints, _ = d['points'].shape
    points = d['points']
    scores = d['scores']

    bodyparts = d['bodyparts']

    # remove points that are below threshold
    points[scores < score_threshold] = np.nan

    points_flat = points.reshape(n_cams, -1, 2)
    scores_flat = scores.reshape(n_cams, -1)

    p3ds_flat = cgroup.triangulate(points_flat, progress=True)
    reprojerr_flat = cgroup.reprojection_error(p3ds_flat, points_flat, mean=True)

    p3ds = p3ds_flat.reshape(n_points, n_joints, 3)
    reprojerr = reprojerr_flat.reshape(n_points, n_joints)

# %%
## save the new files - animal 2 scorch
if do_3dconstruct:
    bodyparts_3d_scorch_anipose = {}
    nbodyparts = np.shape(bodyparts)[0]
    for ibodypart in np.arange(0,nbodyparts,1):
        # remove outlier
        ind_outlier_x = (p3ds[:,ibodypart,0]<(np.nanmean(p3ds[:,ibodypart,0])-2*np.nanstd(p3ds[:,ibodypart,0])))|(p3ds[:,ibodypart,0]>(np.nanmean(p3ds[:,ibodypart,0])+2*np.nanstd(p3ds[:,ibodypart,0])))
        p3ds[ind_outlier_x,ibodypart,0]=np.nan
        ind_outlier_y = (p3ds[:,ibodypart,1]<(np.nanmean(p3ds[:,ibodypart,1])-2*np.nanstd(p3ds[:,ibodypart,1])))|(p3ds[:,ibodypart,1]>(np.nanmean(p3ds[:,ibodypart,1])+2*np.nanstd(p3ds[:,ibodypart,1])))
        p3ds[ind_outlier_y,ibodypart,1]=np.nan
        ind_outlier_z = (p3ds[:,ibodypart,2]<(np.nanmean(p3ds[:,ibodypart,2])-2*np.nanstd(p3ds[:,ibodypart,2])))|(p3ds[:,ibodypart,2]>(np.nanmean(p3ds[:,ibodypart,2])+2*np.nanstd(p3ds[:,ibodypart,2])))
        p3ds[ind_outlier_z,ibodypart,2]=np.nan
        
        bodyparts_3d_scorch_anipose[('weikang','scorch',bodyparts[ibodypart],'x')] = p3ds[:,ibodypart, 0]
        bodyparts_3d_scorch_anipose[('weikang','scorch',bodyparts[ibodypart],'y')] = p3ds[:,ibodypart, 1]
        bodyparts_3d_scorch_anipose[('weikang','scorch',bodyparts[ibodypart],'z')] = p3ds[:,ibodypart, 2]
    bodyparts_3d_scorch_anipose = pd.DataFrame(bodyparts_3d_scorch_anipose)

# %%
## combine the two animals 
if do_3dconstruct:
    bodyparts_3d_anipose = pd.concat([bodyparts_3d_dodson_anipose,bodyparts_3d_scorch_anipose],axis=1)

    # save the combine the two animal 3d file
    import os
    current_dir = os.getcwd()
    add_date_dir = current_dir+'/anipose_3d_h5_files/'+date_tgt+'_'+animal1+'_'+animal2
    if not os.path.exists(add_date_dir):
        os.makedirs(add_date_dir)
    bodyparts_3d_anipose_file = add_date_dir+'/'+date_tgt+'_'+animal1+'_'+animal2+'_anipose.h5'
    bodyparts_3d_anipose.to_hdf(bodyparts_3d_anipose_file,key='tracks')

# %%
## load saved 3d_anipose h5 file
if not do_3dconstruct:
    import os
    current_dir = os.getcwd()
    add_date_dir = current_dir+'/anipose_3d_h5_files/'+date_tgt+'_'+animal1+'_'+animal2
    bodyparts_3d_anipose_file = add_date_dir+'/'+date_tgt+'_'+animal1+'_'+animal2+'_anipose.h5'
    bodyparts_3d_anipose = pd.read_hdf(bodyparts_3d_anipose_file)

# %%
bodyparts_3d_anipose
# Out:
#         weikang                                                               \
#          dodson
#       rightTuft                     whiteBlaze                      leftTuft
#               x         y         z          x         y         z         x
# 0     -0.879194 -2.439723  7.422631  -0.473267 -1.768463  7.143519  0.482411
# 1     -0.870243 -2.436326  7.422002  -0.480692 -1.750259  7.150687  0.481620
# 2     -0.865233 -2.432228  7.415379  -0.480692 -1.750259  7.150687  0.481518
# 3     -0.836334 -2.550770  7.383898  -0.479844 -1.807049  7.125149  0.460184
# 4     -0.833282 -2.575610  7.369653  -0.510739 -1.826929  7.092327  0.440591
# ...         ...       ...       ...        ...       ...       ...       ...
# 21205  1.297949 -0.583491  7.649065   2.014435 -0.086811  7.124956  2.783910
# 21206  1.296143 -0.583583  7.647748   2.014320 -0.082004  7.108411  2.784226
# 21207  1.279845 -0.579634  7.639706   2.014320 -0.082004  7.108411  2.759290
# 21208  1.273390 -0.581643  7.635438   2.011193 -0.083226  7.108684  2.753632
# 21209  1.255416 -0.590769  7.635796   1.982056 -0.094458  7.098172  2.747613
#
#                                      ...                                  \
#                                      ...     scorch
#                            rightEye  ... boxCorner1 boxCorner2
#               y         z         x  ...          z          x         y
# 0     -1.948474  7.392247 -0.716198  ...   6.860012  -6.452277 -0.299554
# 1     -1.946802  7.392795 -0.716019  ...   6.860012  -6.452277 -0.299554
# 2     -1.946585  7.392866 -0.715966  ...   6.860012  -6.452277 -0.299554
# 3     -1.962323  7.380978 -0.745024  ...   6.860012  -6.452277 -0.299554
# 4     -1.955792  7.372227 -0.754890  ...   6.860012  -6.452277 -0.299554
# ...         ...       ...       ...  ...        ...        ...       ...
# 21205  0.041137  7.559656  1.677848  ...   6.860012  -6.452277 -0.299554
# 21206  0.041463  7.558549  1.677884  ...   6.860012  -6.452277 -0.299554
# 21207  0.047979  7.541884  1.658722  ...   6.860012  -6.452277 -0.299554
# 21208  0.045168  7.538979  1.650001  ...   6.860012  -6.452277 -0.299554
# 21209  0.040469  7.538693  1.633526  ...   6.860012  -6.452277 -0.299554
#
#
#
#                 boxCorner3                      boxCorner4
#               z          x         y          z          x        y          z
# 0      8.825962 -13.175248 -3.647525  10.814858   -9.65081 -6.92189  18.028582
# 1      8.825962 -13.175248 -3.647525  10.814858   -9.65081 -6.92189  18.028582
# 2      8.825962 -13.175248 -3.647525  10.814858   -9.65081 -6.92189  18.028582
# 3      8.825962 -13.175248 -3.647525  10.814858   -9.65081 -6.92189  18.028582
# 4      8.825962 -13.175248 -3.647525  10.814858   -9.65081 -6.92189  18.028582
# ...         ...        ...       ...        ...        ...      ...        ...
# 21205  8.825962 -13.175248 -3.647525  10.814858   -9.65081 -6.92189  18.028582
# 21206  8.825962 -13.175248 -3.647525  10.814858   -9.65081 -6.92189  18.028582
# 21207  8.825962 -13.175248 -3.647525  10.814858   -9.65081 -6.92189  18.028582
# 21208  8.825962 -13.175248 -3.647525  10.814858   -9.65081 -6.92189  18.028582
# 21209  8.825962 -13.175248 -3.647525  10.814858   -9.65081 -6.92189  18.028582
#
# [21210 rows x 72 columns]

# %%
# plot the x, y, z coordinates of joint 1

import matplotlib.pyplot as plt
# %matplotlib notebook

plt.figure(figsize=(9.4, 6))
plt.plot(bodyparts_3d_anipose[('weikang','dodson','rightTuft','x')])
plt.plot(bodyparts_3d_anipose[('weikang','dodson','rightTuft','y')])
plt.plot(bodyparts_3d_anipose[('weikang','dodson','rightTuft','z')])
plt.xlabel("Time (frames)")
plt.ylabel("Coordinate (mm)")
plt.title("x, y, z coordinates of {}".format('rightTuft'))
# Out:
# <img src="data:image/png;base64,..." width="940">
# Text(0.5, 1.0, 'x, y, z coordinates of rightTuft')

# %%
## plot the example videos

import sys
sys.path.append('/home/ws523/marmoset_tracking_DLCv2/following_up_analysis/3d_recontruction_analysis_self_and_coop_task/ana_functions')
from tracking_video_3d_demo import tracking_video_3d_demo

animalnames_videotrack = ['dodson','scorch']
bodypartnames_videotrack = ['rightTuft','whiteBlaze','leftTuft','rightEye','leftEye','mouth','lever','tube','boxCorner1','boxCorner2','boxCorner3','boxCorner4']
animal1_filename = animal1
animal2_filename = animal2
session_start_time = 1.00
fps = 30
nframes = 2*fps

withboxCorner = 1

current_dir = os.getcwd()
add_date_dir = current_dir+'/anipose_3d_demo_videos/'+date_tgt+'_'+animal1_filename+'_'+animal2_filename
if not os.path.exists(add_date_dir):
    os.makedirs(add_date_dir)
video_file = add_date_dir+'/'+date_tgt+'_'+animal1_filename+'_'+animal2_filename+'_anipose_3d_tracking_demo.mp4'

tracking_video_3d_demo(bodyparts_3d_anipose['weikang'],animalnames_videotrack,bodypartnames_videotrack,date_tgt,animal1_filename,animal2_filename,session_start_time,fps,nframes,video_file,withboxCorner)
# Out:
# <img src="data:image/png;base64,..." width="1500">
# printing frame  31 / 90
# printing frame  32 / 90
# printing frame  33 / 90
# printing frame  34 / 90
# printing frame  35 / 90
# printing frame  36 / 90
# printing frame  37 / 90
# printing frame  38 / 90
# printing frame  39 / 90
# printing frame  40 / 90
# printing frame  41 / 90
# printing frame  42 / 90
# printing frame  43 / 90
# printing frame  44 / 90
# printing frame  45 / 90
# printing frame  46 / 90
# printing frame  47 / 90
# printing frame  48 / 90
# printing frame  49 / 90
# printing frame  50 / 90
# printing frame  51 / 90
# printing frame  52 / 90
# printing frame  53 / 90
# printing frame  54 / 90
# printing frame  55 / 90
# printing frame  56 / 90
# printing frame  57 / 90
# printing frame  58 / 90
# printing frame  59 / 90
# printing frame  60 / 90
# printing frame  61 / 90
# printing frame  62 / 90
# printing frame  63 / 90
# printing frame  64 / 90
# printing frame  65 / 90
# printing frame  66 / 90
# printing frame  67 / 90
# printing frame  68 / 90
# printing frame  69 / 90
# printing frame  70 / 90
# printing frame  71 / 90
# printing frame  72 / 90
# printing frame  73 / 90
# printing frame  74 / 90
# printing frame  75 / 90
# printing frame  76 / 90
# printing frame  77 / 90
# printing frame  78 / 90
# printing frame  79 / 90
# printing frame  80 / 90
# printing frame  81 / 90
# printing frame  82 / 90
# printing frame  83 / 90
# printing frame  84 / 90
# printing frame  85 / 90
# printing frame  86 / 90
# printing frame  87 / 90
# printing frame  88 / 90
# printing frame  89 / 90
# printing frame  90 / 90

# %%
## plot the example videos
## for comparison make the video based on DLC's own 3d recontruction

twocamera_videos_cam12 = "/gpfs/gibbs/pi/jadi/VideoTracker_SocialInter/test_video_cooperative_task_3d/"+date_tgt+"_"+animal1+"_"+animal2+"_camera12/"
twocamera_videos_cam23 = "/gpfs/gibbs/pi/jadi/VideoTracker_SocialInter/test_video_cooperative_task_3d/"+date_tgt+"_"+animal1+"_"+animal2+"_camera23/"

bodyparts_cam1_cam12 = twocamera_videos_cam12+date_tgt+"_"+animal1+"_"+animal2+"_camera-1"+singlecam_ana_type+"_el_filtered.h5"
bodyparts_cam2_cam12 = twocamera_videos_cam12+date_tgt+"_"+animal1+"_"+animal2+"_camera-2"+singlecam_ana_type+"_el_filtered.h5"
bodyparts_cam3_cam23 = twocamera_videos_cam23+date_tgt+"_"+animal1+"_"+animal2+"_camera-3"+singlecam_ana_type+"_el_filtered.h5"

bodyparts_3d_cam12_DLC = twocamera_videos_cam12+date_tgt+"_"+animal1+"_"+animal2+"_weikang.h5"
bodyparts_3d_cam23_DLC = twocamera_videos_cam23+date_tgt+"_"+animal1+"_"+animal2+"_weikang.h5"

singlecam_ana_type = "DLC_dlcrnetms5_marmoset_tracking_with_middle_cameraSep1shuffle1_150000"

bodyparts_3d_cam12_DLC_data = pd.read_hdf(bodyparts_3d_cam12_DLC)
bodyparts_3d_cam23_DLC_data = pd.read_hdf(bodyparts_3d_cam23_DLC)


# camera 12 pair

import sys
sys.path.append('/home/ws523/marmoset_tracking_DLCv2/following_up_analysis/3d_recontruction_analysis_self_and_coop_task/ana_functions')
from tracking_video_3d_demo import tracking_video_3d_demo

animalnames_videotrack = ['dodson','scorch']
bodypartnames_videotrack = ['rightTuft','whiteBlaze','leftTuft','rightEye','leftEye','mouth']
animal1_filename = animal1
animal2_filename = animal2
session_start_time = 1.00
fps = 30
nframes = 60*fps

withboxCorner = 0

current_dir = os.getcwd()
add_date_dir = current_dir+'/DLC_cam12_3d_demo_videos/'+date_tgt+'_'+animal1_filename+'_'+animal2_filename
if not os.path.exists(add_date_dir):
    os.makedirs(add_date_dir)
video_file = add_date_dir+'/'+date_tgt+'_'+animal1_filename+'_'+animal2_filename+'_DLCcam12_3d_tracking_demo.mp4'

tracking_video_3d_demo(bodyparts_3d_cam12_DLC_data['weikang'],animalnames_videotrack,bodypartnames_videotrack,date_tgt,animal1_filename,animal2_filename,session_start_time,fps,nframes,video_file,withboxCorner)



# camera 23 pair

import sys
sys.path.append('/home/ws523/marmoset_tracking_DLCv2/following_up_analysis/3d_recontruction_analysis_self_and_coop_task/ana_functions')
from tracking_video_3d_demo import tracking_video_3d_demo

animalnames_videotrack = ['dodson','scorch']
bodypartnames_videotrack = ['rightTuft','whiteBlaze','leftTuft','rightEye','leftEye','mouth']
animal1_filename = animal1
animal2_filename = animal2
session_start_time = 1.00
fps = 30
nframes = 60*fps

withboxCorner = 0

current_dir = os.getcwd()
add_date_dir = current_dir+'/DLC_cam23_3d_demo_videos/'+date_tgt+'_'+animal1_filename+'_'+animal2_filename
if not os.path.exists(add_date_dir):
    os.makedirs(add_date_dir)
video_file = add_date_dir+'/'+date_tgt+'_'+animal1_filename+'_'+animal2_filename+'_DLCcam23_3d_tracking_demo.mp4'

tracking_video_3d_demo(bodyparts_3d_cam23_DLC_data['weikang'],animalnames_videotrack,bodypartnames_videotrack,date_tgt,animal1_filename,animal2_filename,session_start_time,fps,nframes,video_file,withboxCorner)
# Out:
# <img src="data:image/png;base64,..." width="1500">
# printing frame  31 / 1830
# printing frame  32 / 1830
# printing frame  33 / 1830
# printing frame  34 / 1830
# printing frame  35 / 1830
# printing frame  36 / 1830
# printing frame  37 / 1830
# printing frame  38 / 1830
# printing frame  39 / 1830
# printing frame  40 / 1830
# printing frame  41 / 1830
# printing frame  42 / 1830
# printing frame  43 / 1830
# printing frame  44 / 1830
# printing frame  45 / 1830
# printing frame  46 / 1830
# printing frame  47 / 1830
# printing frame  48 / 1830
# printing frame  49 / 1830
# printing frame  50 / 1830
# printing frame  51 / 1830
# printing frame  52 / 1830
# printing frame  53 / 1830
# printing frame  54 / 1830
# printing frame  55 / 1830
# printing frame  56 / 1830
# printing frame  57 / 1830
# printing frame  58 / 1830
# printing frame  59 / 1830
# printing frame  60 / 1830
# printing frame  61 / 1830
# printing frame  62 / 1830
# printing frame  63 / 1830
# printing frame  64 / 1830
# printing frame  65 / 1830
# printing frame  66 / 1830
# printing frame  67 / 1830
# printing frame  68 / 1830
# printing frame  69 / 1830
# printing frame  70 / 1830
# printing frame  71 / 1830
# printing frame  72 / 1830
# printing frame  73 / 1830
# printing frame  74 / 1830
# printing frame  75 / 1830
# printing frame  76 / 1830
# printing frame  77 / 1830
# printing frame  78 / 1830
# printing frame  79 / 1830
# printing frame  80 / 1830
# printing frame  81 / 1830
# printing frame  82 / 1830
# printing frame  83 / 1830
# printing frame  84 / 1830
# printing frame  85 / 1830
# printing frame  86 / 1830
# printing frame  87 / 1830
# printing frame  88 / 1830
# printing frame  89 / 1830
# printing frame  90 / 1830
# printing frame  91 / 1830
# printing frame  92 / 1830
# printing frame  93 / 1830
# printing frame  94 / 1830
# printing frame  95 / 1830
# printing frame  96 / 1830
# printing frame  97 / 1830
# printing frame  98 / 1830
# printing frame  99 / 1830
# printing frame  100 / 1830
# printing frame  101 / 1830
# printing frame  102 / 1830
# printing frame  103 / 1830
# printing frame  104 / 1830
# printing frame  105 / 1830
# printing frame  106 / 1830
# printing frame  107 / 1830
# printing frame  108 / 1830
# printing frame  109 / 1830
# printing frame  110 / 1830
# printing frame  111 / 1830
# printing frame  112 / 1830
# printing frame  113 / 1830
# printing frame  114 / 1830
# printing frame  115 / 1830
# printing frame  116 / 1830
# printing frame  117 / 1830
# printing frame  118 / 1830
# printing frame  119 / 1830
# printing frame  120 / 1830
# printing frame  121 / 1830
# printing frame  122 / 1830
# printing frame  123 / 1830
# printing frame  124 / 1830
# printing frame  125 / 1830
# printing frame  126 / 1830
# printing frame  127 / 1830
# printing frame  128 / 1830
# printing frame  129 / 1830
# printing frame  130 / 1830
# printing frame  131 / 1830
# printing frame  132 / 1830
# printing frame  133 / 1830
# printing frame  134 / 1830
# printing frame  135 / 1830
# printing frame  136 / 1830
# printing frame  137 / 1830
# printing frame  138 / 1830
# printing frame  139 / 1830
# printing frame  140 / 1830
# printing frame  141 / 1830
# printing frame  142 / 1830
# printing frame  143 / 1830
# printing frame  144 / 1830
# printing frame  145 / 1830
# printing frame  146 / 1830
# printing frame  147 / 1830
# printing frame  148 / 1830
# printing frame  149 / 1830
# printing frame  150 / 1830
# printing frame  151 / 1830
# printing frame  152 / 1830
# printing frame  153 / 1830
# printing frame  154 / 1830
# printing frame  155 / 1830
# printing frame  156 / 1830
# printing frame  157 / 1830
# printing frame  158 / 1830
# printing frame  159 / 1830
# printing frame  160 / 1830
# printing frame  161 / 1830
# printing frame  162 / 1830
# printing frame  163 / 1830
# printing frame  164 / 1830
# printing frame  165 / 1830
# printing frame  166 / 1830
# printing frame  167 / 1830
# printing frame  168 / 1830
# printing frame  169 / 1830
# printing frame  170 / 1830
# printing frame  171 / 1830
# printing frame  172 / 1830
# printing frame  173 / 1830
# printing frame  174 / 1830
# printing frame  175 / 1830
# printing frame  176 / 1830
# printing frame  177 / 1830
# printing frame  178 / 1830
# printing frame  179 / 1830
# printing frame  180 / 1830
# printing frame  181 / 1830
# printing frame  182 / 1830
# printing frame  183 / 1830
# printing frame  184 / 1830
# printing frame  185 / 1830
# printing frame  186 / 1830
# printing frame  187 / 1830
# printing frame  188 / 1830
# printing frame  189 / 1830
# printing frame  190 / 1830
# printing frame  191 / 1830
# printing frame  192 / 1830
# printing frame  193 / 1830
# printing frame  194 / 1830
# printing frame  195 / 1830
# printing frame  196 / 1830
# printing frame  197 / 1830
# printing frame  198 / 1830
# printing frame  199 / 1830
# printing frame  200 / 1830
# printing frame  201 / 1830
# printing frame  202 / 1830
# printing frame  203 / 1830
# printing frame  204 / 1830
# printing frame  205 / 1830
# printing frame  206 / 1830
# printing frame  207 / 1830
# printing frame  208 / 1830
# printing frame  209 / 1830
# printing frame  210 / 1830
# printing frame  211 / 1830
# printing frame  212 / 1830
# printing frame  213 / 1830
# printing frame  214 / 1830
# printing frame  215 / 1830
# printing frame  216 / 1830
# printing frame  217 / 1830
# printing frame  218 / 1830
# printing frame  219 / 1830
# printing frame  220 / 1830
# printing frame  221 / 1830
# printing frame  222 / 1830
# printing frame  223 / 1830
# printing frame  224 / 1830
# printing frame  225 / 1830
# printing frame  226 / 1830
# printing frame  227 / 1830
# printing frame  228 / 1830
# printing frame  229 / 1830
# printing frame  230 / 1830
# printing frame  231 / 1830
# printing frame  232 / 1830
# printing frame  233 / 1830
# printing frame  234 / 1830
# printing frame  235 / 1830
# printing frame  236 / 1830
# printing frame  237 / 1830
# printing frame  238 / 1830
# printing frame  239 / 1830
# printing frame  240 / 1830
# printing frame  241 / 1830
# printing frame  242 / 1830
# printing frame  243 / 1830
# printing frame  244 / 1830
# printing frame  245 / 1830
# printing frame  246 / 1830
# printing frame  247 / 1830
# printing frame  248 / 1830
# printing frame  249 / 1830
# printing frame  250 / 1830
# printing frame  251 / 1830
# printing frame  252 / 1830
# printing frame  253 / 1830
# printing frame  254 / 1830
# printing frame  255 / 1830
# printing frame  256 / 1830
# printing frame  257 / 1830
# printing frame  258 / 1830
# printing frame  259 / 1830
# printing frame  260 / 1830
# printing frame  261 / 1830
# printing frame  262 / 1830
# printing frame  263 / 1830
# printing frame  264 / 1830
# printing frame  265 / 1830
# printing frame  266 / 1830
# printing frame  267 / 1830
# printing frame  268 / 1830
# printing frame  269 / 1830
# printing frame  270 / 1830
# printing frame  271 / 1830
# printing frame  272 / 1830
# printing frame  273 / 1830
# printing frame  274 / 1830
# printing frame  275 / 1830
# printing frame  276 / 1830
# printing frame  277 / 1830
# printing frame  278 / 1830
# printing frame  279 / 1830
# printing frame  280 / 1830
# printing frame  281 / 1830
# printing frame  282 / 1830
# printing frame  283 / 1830
# printing frame  284 / 1830
# printing frame  285 / 1830
# printing frame  286 / 1830
# printing frame  287 / 1830
# printing frame  288 / 1830
# printing frame  289 / 1830
# printing frame  290 / 1830
# printing frame  291 / 1830
# printing frame  292 / 1830
# printing frame  293 / 1830
# printing frame  294 / 1830
# printing frame  295 / 1830
# printing frame  296 / 1830
# printing frame  297 / 1830
# printing frame  298 / 1830
# printing frame  299 / 1830
# printing frame  300 / 1830
# printing frame  301 / 1830
# printing frame  302 / 1830
# printing frame  303 / 1830
# printing frame  304 / 1830
# printing frame  305 / 1830
# printing frame  306 / 1830
# printing frame  307 / 1830
# printing frame  308 / 1830
# printing frame  309 / 1830
# printing frame  310 / 1830
# printing frame  311 / 1830
# printing frame  312 / 1830
# printing frame  313 / 1830
# printing frame  314 / 1830
# printing frame  315 / 1830
# printing frame  316 / 1830
# printing frame  317 / 1830
# printing frame  318 / 1830
# printing frame  319 / 1830
# printing frame  320 / 1830
# printing frame  321 / 1830
# printing frame  322 / 1830
# printing frame  323 / 1830
# printing frame  324 / 1830
# printing frame  325 / 1830
# printing frame  326 / 1830
# printing frame  327 / 1830
# printing frame  328 / 1830
# printing frame  329 / 1830
# printing frame  330 / 1830
# printing frame  331 / 1830
# printing frame  332 / 1830
# printing frame  333 / 1830
# printing frame  334 / 1830
# printing frame  335 / 1830
# printing frame  336 / 1830
# printing frame  337 / 1830
# printing frame  338 / 1830
# printing frame  339 / 1830
# printing frame  340 / 1830
# printing frame  341 / 1830
# printing frame  342 / 1830
# printing frame  343 / 1830
# printing frame  344 / 1830
# printing frame  345 / 1830
# printing frame  346 / 1830
# printing frame  347 / 1830
# printing frame  348 / 1830
# printing frame  349 / 1830
# printing frame  350 / 1830
# printing frame  351 / 1830
# printing frame  352 / 1830
# printing frame  353 / 1830
# printing frame  354 / 1830
# printing frame  355 / 1830
# printing frame  356 / 1830
# printing frame  357 / 1830
# printing frame  358 / 1830
# printing frame  359 / 1830
# printing frame  360 / 1830
# printing frame  361 / 1830
# printing frame  362 / 1830
# printing frame  363 / 1830
# printing frame  364 / 1830
# printing frame  365 / 1830
# printing frame  366 / 1830
# printing frame  367 / 1830
# printing frame  368 / 1830
# printing frame  369 / 1830
# printing frame  370 / 1830
# printing frame  371 / 1830
# printing frame  372 / 1830
# printing frame  373 / 1830
# printing frame  374 / 1830
# printing frame  375 / 1830
# printing frame  376 / 1830
# printing frame  377 / 1830
# printing frame  378 / 1830
# printing frame  379 / 1830
# printing frame  380 / 1830
# printing frame  381 / 1830
# printing frame  382 / 1830
# printing frame  383 / 1830
# printing frame  384 / 1830
# printing frame  385 / 1830
# printing frame  386 / 1830
# printing frame  387 / 1830
# printing frame  388 / 1830
# printing frame  389 / 1830
# printing frame  390 / 1830
# printing frame  391 / 1830
# printing frame  392 / 1830
# printing frame  393 / 1830
# printing frame  394 / 1830
# printing frame  395 / 1830
# printing frame  396 / 1830
# printing frame  397 / 1830
# printing frame  398 / 1830
# printing frame  399 / 1830
# printing frame  400 / 1830
# printing frame  401 / 1830
# printing frame  402 / 1830
# printing frame  403 / 1830
# printing frame  404 / 1830
# printing frame  405 / 1830
# printing frame  406 / 1830
# printing frame  407 / 1830
# printing frame  408 / 1830
# printing frame  409 / 1830
# printing frame  410 / 1830
# printing frame  411 / 1830
# printing frame  412 / 1830
# printing frame  413 / 1830
# printing frame  414 / 1830
# printing frame  415 / 1830
# printing frame  416 / 1830
# printing frame  417 / 1830
# printing frame  418 / 1830
# printing frame  419 / 1830
# printing frame  420 / 1830
# printing frame  421 / 1830
# printing frame  422 / 1830
# printing frame  423 / 1830
# printing frame  424 / 1830
# printing frame  425 / 1830
# printing frame  426 / 1830
# printing frame  427 / 1830
# printing frame  428 / 1830
# printing frame  429 / 1830
# printing frame  430 / 1830
# printing frame  431 / 1830
# printing frame  432 / 1830
# printing frame  433 / 1830
# printing frame  434 / 1830
# printing frame  435 / 1830
# printing frame  436 / 1830
# printing frame  437 / 1830
# printing frame  438 / 1830
# printing frame  439 / 1830
# printing frame  440 / 1830
# printing frame  441 / 1830
# printing frame  442 / 1830
# printing frame  443 / 1830
# printing frame  444 / 1830
# printing frame  445 / 1830
# printing frame  446 / 1830
# printing frame  447 / 1830
# printing frame  448 / 1830
# printing frame  449 / 1830
# printing frame  450 / 1830
# printing frame  451 / 1830
# printing frame  452 / 1830
# printing frame  453 / 1830
# printing frame  454 / 1830
# printing frame  455 / 1830
# printing frame  456 / 1830
# printing frame  457 / 1830
# printing frame  458 / 1830
# printing frame  459 / 1830
# printing frame  460 / 1830
# printing frame  461 / 1830
# printing frame  462 / 1830
# printing frame  463 / 1830
# printing frame  464 / 1830
# printing frame  465 / 1830
# printing frame  466 / 1830
# printing frame  467 / 1830
# printing frame  468 / 1830
# printing frame  469 / 1830
# printing frame  470 / 1830
# printing frame  471 / 1830
# printing frame  472 / 1830
# printing frame  473 / 1830
# printing frame  474 / 1830
# printing frame  475 / 1830
# printing frame  476 / 1830
# printing frame  477 / 1830
# printing frame  478 / 1830
# printing frame  479 / 1830
# printing frame  480 / 1830
# printing frame  481 / 1830
# printing frame  482 / 1830
# printing frame  483 / 1830
# printing frame  484 / 1830
# printing frame  485 / 1830
# printing frame  486 / 1830
# printing frame  487 / 1830
# printing frame  488 / 1830
# printing frame  489 / 1830
# printing frame  490 / 1830
# printing frame  491 / 1830
# printing frame  492 / 1830
# printing frame  493 / 1830
# printing frame  494 / 1830
# printing frame  495 / 1830
# printing frame  496 / 1830
# printing frame  497 / 1830
# printing frame  498 / 1830
# printing frame  499 / 1830
# printing frame  500 / 1830
# printing frame  501 / 1830
# printing frame  502 / 1830
# printing frame  503 / 1830
# printing frame  504 / 1830
# printing frame  505 / 1830
# printing frame  506 / 1830
# printing frame  507 / 1830
# printing frame  508 / 1830
# printing frame  509 / 1830
# printing frame  510 / 1830
# printing frame  511 / 1830
# printing frame  512 / 1830
# printing frame  513 / 1830
# printing frame  514 / 1830
# printing frame  515 / 1830
# printing frame  516 / 1830
# printing frame  517 / 1830
# printing frame  518 / 1830
# printing frame  519 / 1830
# printing frame  520 / 1830
# printing frame  521 / 1830
# printing frame  522 / 1830
# printing frame  523 / 1830
# printing frame  524 / 1830
# printing frame  525 / 1830
# printing frame  526 / 1830
# printing frame  527 / 1830
# printing frame  528 / 1830
# printing frame  529 / 1830
# printing frame  530 / 1830
# printing frame  531 / 1830
# printing frame  532 / 1830
# printing frame  533 / 1830
# printing frame  534 / 1830
# printing frame  535 / 1830
# printing frame  536 / 1830
# printing frame  537 / 1830
# printing frame  538 / 1830
# printing frame  539 / 1830
# printing frame  540 / 1830
# printing frame  541 / 1830
# printing frame  542 / 1830
# printing frame  543 / 1830
# printing frame  544 / 1830
# printing frame  545 / 1830
# printing frame  546 / 1830
# printing frame  547 / 1830
# printing frame  548 / 1830
# printing frame  549 / 1830
# printing frame  550 / 1830
# printing frame  551 / 1830
# printing frame  552 / 1830
# printing frame  553 / 1830
# printing frame  554 / 1830
# printing frame  555 / 1830
# printing frame  556 / 1830
# printing frame  557 / 1830
# printing frame  558 / 1830
# printing frame  559 / 1830
# printing frame  560 / 1830
# printing frame  561 / 1830
# printing frame  562 / 1830
# printing frame  563 / 1830
# printing frame  564 / 1830
# printing frame  565 / 1830
# printing frame  566 / 1830
# printing frame  567 / 1830
# printing frame  568 / 1830
# printing frame  569 / 1830
# printing frame  570 / 1830
# printing frame  571 / 1830
# printing frame  572 / 1830
# printing frame  573 / 1830
# printing frame  574 / 1830
# printing frame  575 / 1830
# printing frame  576 / 1830
# printing frame  577 / 1830
# printing frame  578 / 1830
# printing frame  579 / 1830
# printing frame  580 / 1830
# printing frame  581 / 1830
# printing frame  582 / 1830
# printing frame  583 / 1830
# printing frame  584 / 1830
# printing frame  585 / 1830
# printing frame  586 / 1830
# printing frame  587 / 1830
# printing frame  588 / 1830
# printing frame  589 / 1830
# printing frame  590 / 1830
# printing frame  591 / 1830
# printing frame  592 / 1830
# printing frame  593 / 1830
# printing frame  594 / 1830
# printing frame  595 / 1830
# printing frame  596 / 1830
# printing frame  597 / 1830
# printing frame  598 / 1830
# printing frame  599 / 1830
# printing frame  600 / 1830
# printing frame  601 / 1830
# printing frame  602 / 1830
# printing frame  603 / 1830
# printing frame  604 / 1830
# printing frame  605 / 1830
# printing frame  606 / 1830
# printing frame  607 / 1830
# printing frame  608 / 1830
# printing frame  609 / 1830
# printing frame  610 / 1830
# printing frame  611 / 1830
# printing frame  612 / 1830
# printing frame  613 / 1830
# printing frame  614 / 1830
# printing frame  615 / 1830
# printing frame  616 / 1830
# printing frame  617 / 1830
# printing frame  618 / 1830
# printing frame  619 / 1830
# printing frame  620 / 1830
# printing frame  621 / 1830
# printing frame  622 / 1830
# printing frame  623 / 1830
# printing frame  624 / 1830
# printing frame  625 / 1830
# printing frame  626 / 1830
# printing frame  627 / 1830
# printing frame  628 / 1830
# printing frame  629 / 1830
# printing frame  630 / 1830
# printing frame  631 / 1830
# printing frame  632 / 1830
# printing frame  633 / 1830
# printing frame  634 / 1830
# printing frame  635 / 1830
# printing frame  636 / 1830
# printing frame  637 / 1830
# printing frame  638 / 1830
# printing frame  639 / 1830
# printing frame  640 / 1830
# printing frame  641 / 1830
# printing frame  642 / 1830
# printing frame  643 / 1830
# printing frame  644 / 1830
# printing frame  645 / 1830
# printing frame  646 / 1830
# printing frame  647 / 1830
# printing frame  648 / 1830
# printing frame  649 / 1830
# printing frame  650 / 1830
# printing frame  651 / 1830
# printing frame  652 / 1830
# printing frame  653 / 1830
# printing frame  654 / 1830
# printing frame  655 / 1830
# printing frame  656 / 1830
# printing frame  657 / 1830
# printing frame  658 / 1830
# printing frame  659 / 1830
# printing frame  660 / 1830
# printing frame  661 / 1830
# printing frame  662 / 1830
# printing frame  663 / 1830
# printing frame  664 / 1830
# printing frame  665 / 1830
# printing frame  666 / 1830
# printing frame  667 / 1830
# printing frame  668 / 1830
# printing frame  669 / 1830
# printing frame  670 / 1830
# printing frame  671 / 1830
# printing frame  672 / 1830
# printing frame  673 / 1830
# printing frame  674 / 1830
# printing frame  675 / 1830
# printing frame  676 / 1830
# printing frame  677 / 1830
# printing frame  678 / 1830
# printing frame  679 / 1830
# printing frame  680 / 1830
# printing frame  681 / 1830
# printing frame  682 / 1830
# printing frame  683 / 1830
# printing frame  684 / 1830
# printing frame  685 / 1830
# printing frame  686 / 1830
# printing frame  687 / 1830
# printing frame  688 / 1830
# printing frame  689 / 1830
# printing frame  690 / 1830
# printing frame  691 / 1830
# printing frame  692 / 1830
# printing frame  693 / 1830
# printing frame  694 / 1830
# printing frame  695 / 1830
# printing frame  696 / 1830
# printing frame  697 / 1830
# printing frame  698 / 1830
# printing frame  699 / 1830
# printing frame  700 / 1830
# printing frame  701 / 1830
# printing frame  702 / 1830
# printing frame  703 / 1830
# printing frame  704 / 1830
# printing frame  705 / 1830
# printing frame  706 / 1830
# printing frame  707 / 1830
# printing frame  708 / 1830
# printing frame  709 / 1830
# printing frame  710 / 1830
# printing frame  711 / 1830
# printing frame  712 / 1830
# printing frame  713 / 1830
# printing frame  714 / 1830
# printing frame  715 / 1830
# printing frame  716 / 1830
# printing frame  717 / 1830
# printing frame  718 / 1830
# printing frame  719 / 1830
# printing frame  720 / 1830
# printing frame  721 / 1830
# printing frame  722 / 1830
# printing frame  723 / 1830
# printing frame  724 / 1830
# printing frame  725 / 1830
# printing frame  726 / 1830
# printing frame  727 / 1830
# printing frame  728 / 1830
# printing frame  729 / 1830
# printing frame  730 / 1830
# printing frame  731 / 1830
# printing frame  732 / 1830
# printing frame  733 / 1830
# printing frame  734 / 1830
# printing frame  735 / 1830
# printing frame  736 / 1830
# printing frame  737 / 1830
# printing frame  738 / 1830
# printing frame  739 / 1830
# printing frame  740 / 1830
# printing frame  741 / 1830
# printing frame  742 / 1830
# printing frame  743 / 1830
# printing frame  744 / 1830
# printing frame  745 / 1830
# printing frame  746 / 1830
# printing frame  747 / 1830
# printing frame  748 / 1830
# printing frame  749 / 1830
# printing frame  750 / 1830
# printing frame  751 / 1830
# printing frame  752 / 1830
# printing frame  753 / 1830
# printing frame  754 / 1830
# printing frame  755 / 1830
# printing frame  756 / 1830
# printing frame  757 / 1830
# printing frame  758 / 1830
# printing frame  759 / 1830
# printing frame  760 / 1830
# printing frame  761 / 1830
# printing frame  762 / 1830
# printing frame  763 / 1830
# printing frame  764 / 1830
# printing frame  765 / 1830
# printing frame  766 / 1830
# printing frame  767 / 1830
# printing frame  768 / 1830
# printing frame  769 / 1830
# printing frame  770 / 1830
# printing frame  771 / 1830
# printing frame  772 / 1830
# printing frame  773 / 1830
# printing frame  774 / 1830
# printing frame  775 / 1830
# printing frame  776 / 1830
# printing frame  777 / 1830
# printing frame  778 / 1830
# printing frame  779 / 1830
# printing frame  780 / 1830
# printing frame  781 / 1830
# printing frame  782 / 1830
# printing frame  783 / 1830
# printing frame  784 / 1830
# printing frame  785 / 1830
# printing frame  786 / 1830
# printing frame  787 / 1830
# printing frame  788 / 1830
# printing frame  789 / 1830
# printing frame  790 / 1830
# printing frame  791 / 1830
# printing frame  792 / 1830
# printing frame  793 / 1830
# printing frame  794 / 1830
# printing frame  795 / 1830
# printing frame  796 / 1830
# printing frame  797 / 1830
# printing frame  798 / 1830
# printing frame  799 / 1830
# printing frame  800 / 1830
# printing frame  801 / 1830
# printing frame  802 / 1830
# printing frame  803 / 1830
# printing frame  804 / 1830
# printing frame  805 / 1830
# printing frame  806 / 1830
# printing frame  807 / 1830
# printing frame  808 / 1830
# printing frame  809 / 1830
# printing frame  810 / 1830
# printing frame  811 / 1830
# printing frame  812 / 1830
# printing frame  813 / 1830
# printing frame  814 / 1830
# printing frame  815 / 1830
# printing frame  816 / 1830
# printing frame  817 / 1830
# printing frame  818 / 1830
# printing frame  819 / 1830
# printing frame  820 / 1830
# printing frame  821 / 1830
# printing frame  822 / 1830
# printing frame  823 / 1830
# printing frame  824 / 1830
# printing frame  825 / 1830
# printing frame  826 / 1830
# printing frame  827 / 1830
# printing frame  828 / 1830
# printing frame  829 / 1830
# printing frame  830 / 1830
# printing frame  831 / 1830
# printing frame  832 / 1830
# printing frame  833 / 1830
# printing frame  834 / 1830
# printing frame  835 / 1830
# printing frame  836 / 1830
# printing frame  837 / 1830
# printing frame  838 / 1830
# printing frame  839 / 1830
# printing frame  840 / 1830
# printing frame  841 / 1830
# printing frame  842 / 1830
# printing frame  843 / 1830
# printing frame  844 / 1830
# printing frame  845 / 1830
# printing frame  846 / 1830
# printing frame  847 / 1830
# printing frame  848 / 1830
# printing frame  849 / 1830
# printing frame  850 / 1830
# printing frame  851 / 1830
# printing frame  852 / 1830
# printing frame  853 / 1830
# printing frame  854 / 1830
# printing frame  855 / 1830
# printing frame  856 / 1830
# printing frame  857 / 1830
# printing frame  858 / 1830
# printing frame  859 / 1830
# printing frame  860 / 1830
# printing frame  861 / 1830
# printing frame  862 / 1830
# printing frame  863 / 1830
# printing frame  864 / 1830
# printing frame  865 / 1830
# printing frame  866 / 1830
# printing frame  867 / 1830
# printing frame  868 / 1830
# printing frame  869 / 1830
# printing frame  870 / 1830
# printing frame  871 / 1830
# printing frame  872 / 1830
# printing frame  873 / 1830
# printing frame  874 / 1830
# printing frame  875 / 1830
# printing frame  876 / 1830
# printing frame  877 / 1830
# printing frame  878 / 1830
# printing frame  879 / 1830
# printing frame  880 / 1830
# printing frame  881 / 1830
# printing frame  882 / 1830
# printing frame  883 / 1830
# printing frame  884 / 1830
# printing frame  885 / 1830
# printing frame  886 / 1830
# printing frame  887 / 1830
# printing frame  888 / 1830
# printing frame  889 / 1830
# printing frame  890 / 1830
# printing frame  891 / 1830
# printing frame  892 / 1830
# printing frame  893 / 1830
# printing frame  894 / 1830
# printing frame  895 / 1830
# printing frame  896 / 1830
# printing frame  897 / 1830
# printing frame  898 / 1830
# printing frame  899 / 1830
# printing frame  900 / 1830
# printing frame  901 / 1830
# printing frame  902 / 1830
# printing frame  903 / 1830
# printing frame  904 / 1830
# printing frame  905 / 1830
# printing frame  906 / 1830
# printing frame  907 / 1830
# printing frame  908 / 1830
# printing frame  909 / 1830
# printing frame  910 / 1830
# printing frame  911 / 1830
# printing frame  912 / 1830
# printing frame  913 / 1830
# printing frame  914 / 1830
# printing frame  915 / 1830
# printing frame  916 / 1830
# printing frame  917 / 1830
# printing frame  918 / 1830
# printing frame  919 / 1830
# printing frame  920 / 1830
# printing frame  921 / 1830
# printing frame  922 / 1830
# printing frame  923 / 1830
# printing frame  924 / 1830
# printing frame  925 / 1830
# printing frame  926 / 1830
# printing frame  927 / 1830
# printing frame  928 / 1830
# printing frame  929 / 1830
# printing frame  930 / 1830
# printing frame  931 / 1830
# printing frame  932 / 1830
# printing frame  933 / 1830
# printing frame  934 / 1830
# printing frame  935 / 1830
# printing frame  936 / 1830
# printing frame  937 / 1830
# printing frame  938 / 1830
# printing frame  939 / 1830
# printing frame  940 / 1830
# printing frame  941 / 1830
# printing frame  942 / 1830
# printing frame  943 / 1830
# printing frame  944 / 1830
# printing frame  945 / 1830
# printing frame  946 / 1830
# printing frame  947 / 1830
# printing frame  948 / 1830
# printing frame  949 / 1830
# printing frame  950 / 1830
# printing frame  951 / 1830
# printing frame  952 / 1830
# printing frame  953 / 1830
# printing frame  954 / 1830
# printing frame  955 / 1830
# printing frame  956 / 1830
# printing frame  957 / 1830
# printing frame  958 / 1830
# printing frame  959 / 1830
# printing frame  960 / 1830
# printing frame  961 / 1830
# printing frame  962 / 1830
# printing frame  963 / 1830
# printing frame  964 / 1830
# printing frame  965 / 1830
# printing frame  966 / 1830
# printing frame  967 / 1830
# printing frame  968 / 1830
# printing frame  969 / 1830
# printing frame  970 / 1830
# printing frame  971 / 1830
# printing frame  972 / 1830
# printing frame  973 / 1830
# printing frame  974 / 1830
# printing frame  975 / 1830
# printing frame  976 / 1830
# printing frame  977 / 1830
# printing frame  978 / 1830
# printing frame  979 / 1830
# printing frame  980 / 1830
# printing frame  981 / 1830
# printing frame  982 / 1830
# printing frame  983 / 1830
# printing frame  984 / 1830
# printing frame  985 / 1830
# printing frame  986 / 1830
# printing frame  987 / 1830
# printing frame  988 / 1830
# printing frame  989 / 1830
# printing frame  990 / 1830
# printing frame  991 / 1830
# printing frame  992 / 1830
# printing frame  993 / 1830
# printing frame  994 / 1830
# printing frame  995 / 1830
# printing frame  996 / 1830
# printing frame  997 / 1830
# printing frame  998 / 1830
# printing frame  999 / 1830
# printing frame  1000 / 1830
# printing frame  1001 / 1830
# printing frame  1002 / 1830
# printing frame  1003 / 1830
# printing frame  1004 / 1830
# printing frame  1005 / 1830
# printing frame  1006 / 1830
# printing frame  1007 / 1830
# printing frame  1008 / 1830
# printing frame  1009 / 1830
# printing frame  1010 / 1830
# printing frame  1011 / 1830
# printing frame  1012 / 1830
# printing frame  1013 / 1830
# printing frame  1014 / 1830
# printing frame  1015 / 1830
# printing frame  1016 / 1830
# printing frame  1017 / 1830
# printing frame  1018 / 1830
# printing frame  1019 / 1830
# printing frame  1020 / 1830
# printing frame  1021 / 1830
# printing frame  1022 / 1830
# printing frame  1023 / 1830
# printing frame  1024 / 1830
# printing frame  1025 / 1830
# printing frame  1026 / 1830
# printing frame  1027 / 1830
# printing frame  1028 / 1830
# printing frame  1029 / 1830
# printing frame  1030 / 1830
# printing frame  1031 / 1830
# printing frame  1032 / 1830
# printing frame  1033 / 1830
# printing frame  1034 / 1830
# printing frame  1035 / 1830
# printing frame  1036 / 1830
# printing frame  1037 / 1830
# printing frame  1038 / 1830
# printing frame  1039 / 1830
# printing frame  1040 / 1830
# printing frame  1041 / 1830
# printing frame  1042 / 1830
# printing frame  1043 / 1830
# printing frame  1044 / 1830
# printing frame  1045 / 1830
# printing frame  1046 / 1830
# printing frame  1047 / 1830
# printing frame  1048 / 1830
# printing frame  1049 / 1830
# printing frame  1050 / 1830
# printing frame  1051 / 1830
# printing frame  1052 / 1830
# printing frame  1053 / 1830
# printing frame  1054 / 1830
# printing frame  1055 / 1830
# printing frame  1056 / 1830
# printing frame  1057 / 1830
# printing frame  1058 / 1830
# printing frame  1059 / 1830
# printing frame  1060 / 1830
# printing frame  1061 / 1830
# printing frame  1062 / 1830
# printing frame  1063 / 1830
# printing frame  1064 / 1830
# printing frame  1065 / 1830
# printing frame  1066 / 1830
# printing frame  1067 / 1830
# printing frame  1068 / 1830
# printing frame  1069 / 1830
# printing frame  1070 / 1830
# printing frame  1071 / 1830
# printing frame  1072 / 1830
# printing frame  1073 / 1830
# printing frame  1074 / 1830
# printing frame  1075 / 1830
# printing frame  1076 / 1830
# printing frame  1077 / 1830
# printing frame  1078 / 1830
# printing frame  1079 / 1830
# printing frame  1080 / 1830
# printing frame  1081 / 1830
# printing frame  1082 / 1830
# printing frame  1083 / 1830
# printing frame  1084 / 1830
# printing frame  1085 / 1830
# printing frame  1086 / 1830
# printing frame  1087 / 1830
# printing frame  1088 / 1830
# printing frame  1089 / 1830
# printing frame  1090 / 1830
# printing frame  1091 / 1830
# printing frame  1092 / 1830
# printing frame  1093 / 1830
# printing frame  1094 / 1830
# printing frame  1095 / 1830
# printing frame  1096 / 1830
# printing frame  1097 / 1830
# printing frame  1098 / 1830
# printing frame  1099 / 1830
# printing frame  1100 / 1830
# printing frame  1101 / 1830
# printing frame  1102 / 1830
# printing frame  1103 / 1830
# printing frame  1104 / 1830
# printing frame  1105 / 1830
# printing frame  1106 / 1830
# printing frame  1107 / 1830
# printing frame  1108 / 1830
# printing frame  1109 / 1830
# printing frame  1110 / 1830
# printing frame  1111 / 1830
# printing frame  1112 / 1830
# printing frame  1113 / 1830
# printing frame  1114 / 1830
# printing frame  1115 / 1830
# printing frame  1116 / 1830
# printing frame  1117 / 1830
# printing frame  1118 / 1830
# printing frame  1119 / 1830
# printing frame  1120 / 1830
# printing frame  1121 / 1830
# printing frame  1122 / 1830
# printing frame  1123 / 1830
# printing frame  1124 / 1830
# printing frame  1125 / 1830
# printing frame  1126 / 1830
# printing frame  1127 / 1830
# printing frame  1128 / 1830
# printing frame  1129 / 1830
# printing frame  1130 / 1830
# printing frame  1131 / 1830
# printing frame  1132 / 1830
# printing frame  1133 / 1830
# printing frame  1134 / 1830
# printing frame  1135 / 1830
# printing frame  1136 / 1830
# printing frame  1137 / 1830
# printing frame  1138 / 1830
# printing frame  1139 / 1830
# printing frame  1140 / 1830
# printing frame  1141 / 1830
# printing frame  1142 / 1830
# printing frame  1143 / 1830
# printing frame  1144 / 1830
# printing frame  1145 / 1830
# printing frame  1146 / 1830
# printing frame  1147 / 1830
# printing frame  1148 / 1830
# printing frame  1149 / 1830
# printing frame  1150 / 1830
# printing frame  1151 / 1830
# printing frame  1152 / 1830
# printing frame  1153 / 1830
# printing frame  1154 / 1830
# printing frame  1155 / 1830
# printing frame  1156 / 1830
# printing frame  1157 / 1830
# printing frame  1158 / 1830
# printing frame  1159 / 1830
# printing frame  1160 / 1830
# printing frame  1161 / 1830
# printing frame  1162 / 1830
# printing frame  1163 / 1830
# printing frame  1164 / 1830
# printing frame  1165 / 1830
# printing frame  1166 / 1830
# printing frame  1167 / 1830
# printing frame  1168 / 1830
# printing frame  1169 / 1830
# printing frame  1170 / 1830
# printing frame  1171 / 1830
# printing frame  1172 / 1830
# printing frame  1173 / 1830
# printing frame  1174 / 1830
# printing frame  1175 / 1830
# printing frame  1176 / 1830
# printing frame  1177 / 1830
# printing frame  1178 / 1830
# printing frame  1179 / 1830
# printing frame  1180 / 1830
# printing frame  1181 / 1830
# printing frame  1182 / 1830
# printing frame  1183 / 1830
# printing frame  1184 / 1830
# printing frame  1185 / 1830
# printing frame  1186 / 1830
# printing frame  1187 / 1830
# printing frame  1188 / 1830
# printing frame  1189 / 1830
# printing frame  1190 / 1830
# printing frame  1191 / 1830
# printing frame  1192 / 1830
# printing frame  1193 / 1830
# printing frame  1194 / 1830
# printing frame  1195 / 1830
# printing frame  1196 / 1830
# printing frame  1197 / 1830
# printing frame  1198 / 1830
# printing frame  1199 / 1830
# printing frame  1200 / 1830
# printing frame  1201 / 1830
# printing frame  1202 / 1830
# printing frame  1203 / 1830
# printing frame  1204 / 1830
# printing frame  1205 / 1830
# printing frame  1206 / 1830
# printing frame  1207 / 1830
# printing frame  1208 / 1830
# printing frame  1209 / 1830
# printing frame  1210 / 1830
# printing frame  1211 / 1830
# printing frame  1212 / 1830
# printing frame  1213 / 1830
# printing frame  1214 / 1830
# printing frame  1215 / 1830
# printing frame  1216 / 1830
# printing frame  1217 / 1830
# printing frame  1218 / 1830
# printing frame  1219 / 1830
# printing frame  1220 / 1830
# printing frame  1221 / 1830
# printing frame  1222 / 1830
# printing frame  1223 / 1830
# printing frame  1224 / 1830
# printing frame  1225 / 1830
# printing frame  1226 / 1830
# printing frame  1227 / 1830
# printing frame  1228 / 1830
# printing frame  1229 / 1830
# printing frame  1230 / 1830
# printing frame  1231 / 1830
# printing frame  1232 / 1830
# printing frame  1233 / 1830
# printing frame  1234 / 1830
# printing frame  1235 / 1830
# printing frame  1236 / 1830
# printing frame  1237 / 1830
# printing frame  1238 / 1830
# printing frame  1239 / 1830
# printing frame  1240 / 1830
# printing frame  1241 / 1830
# printing frame  1242 / 1830
# printing frame  1243 / 1830
# printing frame  1244 / 1830
# printing frame  1245 / 1830
# printing frame  1246 / 1830
# printing frame  1247 / 1830
# printing frame  1248 / 1830
# printing frame  1249 / 1830
# printing frame  1250 / 1830
# printing frame  1251 / 1830
# printing frame  1252 / 1830
# printing frame  1253 / 1830
# printing frame  1254 / 1830
# printing frame  1255 / 1830
# printing frame  1256 / 1830
# printing frame  1257 / 1830
# printing frame  1258 / 1830
# printing frame  1259 / 1830
# printing frame  1260 / 1830
# printing frame  1261 / 1830
# printing frame  1262 / 1830
# printing frame  1263 / 1830
# printing frame  1264 / 1830
# printing frame  1265 / 1830
# printing frame  1266 / 1830
# printing frame  1267 / 1830
# printing frame  1268 / 1830
# printing frame  1269 / 1830
# printing frame  1270 / 1830
# printing frame  1271 / 1830
# printing frame  1272 / 1830
# printing frame  1273 / 1830
# printing frame  1274 / 1830
# printing frame  1275 / 1830
# printing frame  1276 / 1830
# printing frame  1277 / 1830
# printing frame  1278 / 1830
# printing frame  1279 / 1830
# printing frame  1280 / 1830
# printing frame  1281 / 1830
# printing frame  1282 / 1830
# printing frame  1283 / 1830
# printing frame  1284 / 1830
# printing frame  1285 / 1830
# printing frame  1286 / 1830
# printing frame  1287 / 1830
# printing frame  1288 / 1830
# printing frame  1289 / 1830
# printing frame  1290 / 1830
# printing frame  1291 / 1830
# printing frame  1292 / 1830
# printing frame  1293 / 1830
# printing frame  1294 / 1830
# printing frame  1295 / 1830
# printing frame  1296 / 1830
# printing frame  1297 / 1830
# printing frame  1298 / 1830
# printing frame  1299 / 1830
# printing frame  1300 / 1830
# printing frame  1301 / 1830
# printing frame  1302 / 1830
# printing frame  1303 / 1830
# printing frame  1304 / 1830
# printing frame  1305 / 1830
# printing frame  1306 / 1830
# printing frame  1307 / 1830
# printing frame  1308 / 1830
# printing frame  1309 / 1830
# printing frame  1310 / 1830
# printing frame  1311 / 1830
# printing frame  1312 / 1830
# printing frame  1313 / 1830
# printing frame  1314 / 1830
# printing frame  1315 / 1830
# printing frame  1316 / 1830
# printing frame  1317 / 1830
# printing frame  1318 / 1830
# printing frame  1319 / 1830
# printing frame  1320 / 1830
# printing frame  1321 / 1830
# printing frame  1322 / 1830
# printing frame  1323 / 1830
# printing frame  1324 / 1830
# printing frame  1325 / 1830
# printing frame  1326 / 1830
# printing frame  1327 / 1830
# printing frame  1328 / 1830
# printing frame  1329 / 1830
# printing frame  1330 / 1830
# printing frame  1331 / 1830
# printing frame  1332 / 1830
# printing frame  1333 / 1830
# printing frame  1334 / 1830
# printing frame  1335 / 1830
# printing frame  1336 / 1830
# printing frame  1337 / 1830
# printing frame  1338 / 1830
# printing frame  1339 / 1830
# printing frame  1340 / 1830
# printing frame  1341 / 1830
# printing frame  1342 / 1830
# printing frame  1343 / 1830
# printing frame  1344 / 1830
# printing frame  1345 / 1830
# printing frame  1346 / 1830
# printing frame  1347 / 1830
# printing frame  1348 / 1830
# printing frame  1349 / 1830
# printing frame  1350 / 1830
# printing frame  1351 / 1830
# printing frame  1352 / 1830
# printing frame  1353 / 1830
# printing frame  1354 / 1830
# printing frame  1355 / 1830
# printing frame  1356 / 1830
# printing frame  1357 / 1830
# printing frame  1358 / 1830
# printing frame  1359 / 1830
# printing frame  1360 / 1830
# printing frame  1361 / 1830
# printing frame  1362 / 1830
# printing frame  1363 / 1830
# printing frame  1364 / 1830
# printing frame  1365 / 1830
# printing frame  1366 / 1830
# printing frame  1367 / 1830
# printing frame  1368 / 1830
# printing frame  1369 / 1830
# printing frame  1370 / 1830
# printing frame  1371 / 1830
# printing frame  1372 / 1830
# printing frame  1373 / 1830
# printing frame  1374 / 1830
# printing frame  1375 / 1830
# printing frame  1376 / 1830
# printing frame  1377 / 1830
# printing frame  1378 / 1830
# printing frame  1379 / 1830
# printing frame  1380 / 1830
# printing frame  1381 / 1830
# printing frame  1382 / 1830
# printing frame  1383 / 1830
# printing frame  1384 / 1830
# printing frame  1385 / 1830
# printing frame  1386 / 1830
# printing frame  1387 / 1830
# printing frame  1388 / 1830
# printing frame  1389 / 1830
# printing frame  1390 / 1830
# printing frame  1391 / 1830
# printing frame  1392 / 1830
# printing frame  1393 / 1830
# printing frame  1394 / 1830
# printing frame  1395 / 1830
# printing frame  1396 / 1830
# printing frame  1397 / 1830
# printing frame  1398 / 1830
# printing frame  1399 / 1830
# printing frame  1400 / 1830
# printing frame  1401 / 1830
# printing frame  1402 / 1830
# printing frame  1403 / 1830
# printing frame  1404 / 1830
# printing frame  1405 / 1830
# printing frame  1406 / 1830
# printing frame  1407 / 1830
# printing frame  1408 / 1830
# printing frame  1409 / 1830
# printing frame  1410 / 1830
# printing frame  1411 / 1830
# printing frame  1412 / 1830
# printing frame  1413 / 1830
# printing frame  1414 / 1830
# printing frame  1415 / 1830
# printing frame  1416 / 1830
# printing frame  1417 / 1830
# printing frame  1418 / 1830
# printing frame  1419 / 1830
# printing frame  1420 / 1830
# printing frame  1421 / 1830
# printing frame  1422 / 1830
# printing frame  1423 / 1830
# printing frame  1424 / 1830
# printing frame  1425 / 1830
# printing frame  1426 / 1830
# printing frame  1427 / 1830
# printing frame  1428 / 1830
# printing frame  1429 / 1830
# printing frame  1430 / 1830
# printing frame  1431 / 1830
# printing frame  1432 / 1830
# printing frame  1433 / 1830
# printing frame  1434 / 1830
# printing frame  1435 / 1830
# printing frame  1436 / 1830
# printing frame  1437 / 1830
# printing frame  1438 / 1830
# printing frame  1439 / 1830
# printing frame  1440 / 1830
# printing frame  1441 / 1830
# printing frame  1442 / 1830
# printing frame  1443 / 1830
# printing frame  1444 / 1830
# printing frame  1445 / 1830
# printing frame  1446 / 1830
# printing frame  1447 / 1830
# printing frame  1448 / 1830
# printing frame  1449 / 1830
# printing frame  1450 / 1830
# printing frame  1451 / 1830
# printing frame  1452 / 1830
# printing frame  1453 / 1830
# printing frame  1454 / 1830
# printing frame  1455 / 1830
# printing frame  1456 / 1830
# printing frame  1457 / 1830
# printing frame  1458 / 1830
# printing frame  1459 / 1830
# printing frame  1460 / 1830
# printing frame  1461 / 1830
# printing frame  1462 / 1830
# printing frame  1463 / 1830
# printing frame  1464 / 1830
# printing frame  1465 / 1830
# printing frame  1466 / 1830
# printing frame  1467 / 1830
# printing frame  1468 / 1830
# printing frame  1469 / 1830
# printing frame  1470 / 1830
# printing frame  1471 / 1830
# printing frame  1472 / 1830
# printing frame  1473 / 1830
# printing frame  1474 / 1830
# printing frame  1475 / 1830
# printing frame  1476 / 1830
# printing frame  1477 / 1830
# printing frame  1478 / 1830
# printing frame  1479 / 1830
# printing frame  1480 / 1830
# printing frame  1481 / 1830
# printing frame  1482 / 1830
# printing frame  1483 / 1830
# printing frame  1484 / 1830
# printing frame  1485 / 1830
# printing frame  1486 / 1830
# printing frame  1487 / 1830
# printing frame  1488 / 1830
# printing frame  1489 / 1830
# printing frame  1490 / 1830
# printing frame  1491 / 1830
# printing frame  1492 / 1830
# printing frame  1493 / 1830
# printing frame  1494 / 1830
# printing frame  1495 / 1830
# printing frame  1496 / 1830
# printing frame  1497 / 1830
# printing frame  1498 / 1830
# printing frame  1499 / 1830
# printing frame  1500 / 1830
# printing frame  1501 / 1830
# printing frame  1502 / 1830
# printing frame  1503 / 1830
# printing frame  1504 / 1830
# printing frame  1505 / 1830
# printing frame  1506 / 1830
# printing frame  1507 / 1830
# printing frame  1508 / 1830
# printing frame  1509 / 1830
# printing frame  1510 / 1830
# printing frame  1511 / 1830
# printing frame  1512 / 1830
# printing frame  1513 / 1830
# printing frame  1514 / 1830
# printing frame  1515 / 1830
# printing frame  1516 / 1830
# printing frame  1517 / 1830
# printing frame  1518 / 1830
# printing frame  1519 / 1830
# printing frame  1520 / 1830
# printing frame  1521 / 1830
# printing frame  1522 / 1830
# printing frame  1523 / 1830
# printing frame  1524 / 1830
# printing frame  1525 / 1830
# printing frame  1526 / 1830
# printing frame  1527 / 1830
# printing frame  1528 / 1830
# printing frame  1529 / 1830
# printing frame  1530 / 1830
# printing frame  1531 / 1830
# printing frame  1532 / 1830
# printing frame  1533 / 1830
# printing frame  1534 / 1830
# printing frame  1535 / 1830
# printing frame  1536 / 1830
# printing frame  1537 / 1830
# printing frame  1538 / 1830
# printing frame  1539 / 1830
# printing frame  1540 / 1830
# printing frame  1541 / 1830
# printing frame  1542 / 1830
# printing frame  1543 / 1830
# printing frame  1544 / 1830
# printing frame  1545 / 1830
# printing frame  1546 / 1830
# printing frame  1547 / 1830
# printing frame  1548 / 1830
# printing frame  1549 / 1830
# printing frame  1550 / 1830
# printing frame  1551 / 1830
# printing frame  1552 / 1830
# printing frame  1553 / 1830
# printing frame  1554 / 1830
# printing frame  1555 / 1830
# printing frame  1556 / 1830
# printing frame  1557 / 1830
# printing frame  1558 / 1830
# printing frame  1559 / 1830
# printing frame  1560 / 1830
# printing frame  1561 / 1830
# printing frame  1562 / 1830
# printing frame  1563 / 1830
# printing frame  1564 / 1830
# printing frame  1565 / 1830
# printing frame  1566 / 1830
# printing frame  1567 / 1830
# printing frame  1568 / 1830
# printing frame  1569 / 1830
# printing frame  1570 / 1830
# printing frame  1571 / 1830
# printing frame  1572 / 1830
# printing frame  1573 / 1830
# printing frame  1574 / 1830
# printing frame  1575 / 1830
# printing frame  1576 / 1830
# printing frame  1577 / 1830
# printing frame  1578 / 1830
# printing frame  1579 / 1830
# printing frame  1580 / 1830
# printing frame  1581 / 1830
# printing frame  1582 / 1830
# printing frame  1583 / 1830
# printing frame  1584 / 1830
# printing frame  1585 / 1830
# printing frame  1586 / 1830
# printing frame  1587 / 1830
# printing frame  1588 / 1830
# printing frame  1589 / 1830
# printing frame  1590 / 1830
# printing frame  1591 / 1830
# printing frame  1592 / 1830
# printing frame  1593 / 1830
# printing frame  1594 / 1830
# printing frame  1595 / 1830
# printing frame  1596 / 1830
# printing frame  1597 / 1830
# printing frame  1598 / 1830
# printing frame  1599 / 1830
# printing frame  1600 / 1830
# printing frame  1601 / 1830
# printing frame  1602 / 1830
# printing frame  1603 / 1830
# printing frame  1604 / 1830
# printing frame  1605 / 1830
# printing frame  1606 / 1830
# printing frame  1607 / 1830
# printing frame  1608 / 1830
# printing frame  1609 / 1830
# printing frame  1610 / 1830
# printing frame  1611 / 1830
# printing frame  1612 / 1830
# printing frame  1613 / 1830
# printing frame  1614 / 1830
# printing frame  1615 / 1830
# printing frame  1616 / 1830
# printing frame  1617 / 1830
# printing frame  1618 / 1830
# printing frame  1619 / 1830
# printing frame  1620 / 1830
# printing frame  1621 / 1830
# printing frame  1622 / 1830
# printing frame  1623 / 1830
# printing frame  1624 / 1830
# printing frame  1625 / 1830
# printing frame  1626 / 1830
# printing frame  1627 / 1830
# printing frame  1628 / 1830
# printing frame  1629 / 1830
# printing frame  1630 / 1830
# printing frame  1631 / 1830
# printing frame  1632 / 1830
# printing frame  1633 / 1830
# printing frame  1634 / 1830
# printing frame  1635 / 1830
# printing frame  1636 / 1830
# printing frame  1637 / 1830
# printing frame  1638 / 1830
# printing frame  1639 / 1830
# printing frame  1640 / 1830
# printing frame  1641 / 1830
# printing frame  1642 / 1830
# printing frame  1643 / 1830
# printing frame  1644 / 1830
# printing frame  1645 / 1830
# printing frame  1646 / 1830
# printing frame  1647 / 1830
# printing frame  1648 / 1830
# printing frame  1649 / 1830
# printing frame  1650 / 1830
# printing frame  1651 / 1830
# printing frame  1652 / 1830
# printing frame  1653 / 1830
# printing frame  1654 / 1830
# printing frame  1655 / 1830
# printing frame  1656 / 1830
# printing frame  1657 / 1830
# printing frame  1658 / 1830
# printing frame  1659 / 1830
# printing frame  1660 / 1830
# printing frame  1661 / 1830
# printing frame  1662 / 1830
# printing frame  1663 / 1830
# printing frame  1664 / 1830
# printing frame  1665 / 1830
# printing frame  1666 / 1830
# printing frame  1667 / 1830
# printing frame  1668 / 1830
# printing frame  1669 / 1830
# printing frame  1670 / 1830
# printing frame  1671 / 1830
# printing frame  1672 / 1830
# printing frame  1673 / 1830
# printing frame  1674 / 1830
# printing frame  1675 / 1830
# printing frame  1676 / 1830
# printing frame  1677 / 1830
# printing frame  1678 / 1830
# printing frame  1679 / 1830
# printing frame  1680 / 1830
# printing frame  1681 / 1830
# printing frame  1682 / 1830
# printing frame  1683 / 1830
# printing frame  1684 / 1830
# printing frame  1685 / 1830
# printing frame  1686 / 1830
# printing frame  1687 / 1830
# printing frame  1688 / 1830
# printing frame  1689 / 1830
# printing frame  1690 / 1830
# printing frame  1691 / 1830
# printing frame  1692 / 1830
# printing frame  1693 / 1830
# printing frame  1694 / 1830
# printing frame  1695 / 1830
# printing frame  1696 / 1830
# printing frame  1697 / 1830
# printing frame  1698 / 1830
# printing frame  1699 / 1830
# printing frame  1700 / 1830
# printing frame  1701 / 1830
# printing frame  1702 / 1830
# printing frame  1703 / 1830
# printing frame  1704 / 1830
# printing frame  1705 / 1830
# printing frame  1706 / 1830
# printing frame  1707 / 1830
# printing frame  1708 / 1830
# printing frame  1709 / 1830
# printing frame  1710 / 1830
# printing frame  1711 / 1830
# printing frame  1712 / 1830
# printing frame  1713 / 1830
# printing frame  1714 / 1830
# printing frame  1715 / 1830
# printing frame  1716 / 1830
# printing frame  1717 / 1830
# printing frame  1718 / 1830
# printing frame  1719 / 1830
# printing frame  1720 / 1830
# printing frame  1721 / 1830
# printing frame  1722 / 1830
# printing frame  1723 / 1830
# printing frame  1724 / 1830
# printing frame  1725 / 1830
# printing frame  1726 / 1830
# printing frame  1727 / 1830
# printing frame  1728 / 1830
# printing frame  1729 / 1830
# printing frame  1730 / 1830
# printing frame  1731 / 1830
# printing frame  1732 / 1830
# printing frame  1733 / 1830
# printing frame  1734 / 1830
# printing frame  1735 / 1830
# printing frame  1736 / 1830
# printing frame  1737 / 1830
# printing frame  1738 / 1830
# printing frame  1739 / 1830
# printing frame  1740 / 1830
# printing frame  1741 / 1830
# printing frame  1742 / 1830
# printing frame  1743 / 1830
# printing frame  1744 / 1830
# printing frame  1745 / 1830
# printing frame  1746 / 1830
# printing frame  1747 / 1830
# printing frame  1748 / 1830
# printing frame  1749 / 1830
# printing frame  1750 / 1830
# printing frame  1751 / 1830
# printing frame  1752 / 1830
# printing frame  1753 / 1830
# printing frame  1754 / 1830
# printing frame  1755 / 1830
# printing frame  1756 / 1830
# printing frame  1757 / 1830
# printing frame  1758 / 1830
# printing frame  1759 / 1830
# printing frame  1760 / 1830
# printing frame  1761 / 1830
# printing frame  1762 / 1830
# printing frame  1763 / 1830
# printing frame  1764 / 1830
# printing frame  1765 / 1830
# printing frame  1766 / 1830
# printing frame  1767 / 1830
# printing frame  1768 / 1830
# printing frame  1769 / 1830
# printing frame  1770 / 1830
# printing frame  1771 / 1830
# printing frame  1772 / 1830
# printing frame  1773 / 1830
# printing frame  1774 / 1830
# printing frame  1775 / 1830
# printing frame  1776 / 1830
# printing frame  1777 / 1830
# printing frame  1778 / 1830
# printing frame  1779 / 1830
# ...
# printing frame  1260 / 1830
# printing frame  1261 / 1830
# printing frame  1262 / 1830
# printing frame  1263 / 1830
# printing frame  1264 / 1830
# printing frame  1265 / 1830
# printing frame  1266 / 1830
# printing frame  1267 / 1830
# printing frame  1268 / 1830
# printing frame  1269 / 1830
# printing frame  1270 / 1830
# printing frame  1271 / 1830
# printing frame  1272 / 1830
# printing frame  1273 / 1830
# printing frame  1274 / 1830
# printing frame  1275 / 1830
# printing frame  1276 / 1830
# printing frame  1277 / 1830
# printing frame  1278 / 1830
# printing frame  1279 / 1830
# printing frame  1280 / 1830
# printing frame  1281 / 1830
# printing frame  1282 / 1830
# printing frame  1283 / 1830
# printing frame  1284 / 1830
# printing frame  1285 / 1830
# printing frame  1286 / 1830
# printing frame  1287 / 1830
# printing frame  1288 / 1830
# printing frame  1289 / 1830
# printing frame  1290 / 1830
# printing frame  1291 / 1830
# printing frame  1292 / 1830
# printing frame  1293 / 1830
# printing frame  1294 / 1830
# printing frame  1295 / 1830
# printing frame  1296 / 1830
# printing frame  1297 / 1830
# printing frame  1298 / 1830
# printing frame  1299 / 1830
# printing frame  1300 / 1830
# printing frame  1301 / 1830
# printing frame  1302 / 1830
# printing frame  1303 / 1830
# printing frame  1304 / 1830
# printing frame  1305 / 1830
# printing frame  1306 / 1830
# printing frame  1307 / 1830
# printing frame  1308 / 1830
# printing frame  1309 / 1830
# printing frame  1310 / 1830
# printing frame  1311 / 1830
# printing frame  1312 / 1830
# printing frame  1313 / 1830
# printing frame  1314 / 1830
# printing frame  1315 / 1830
# printing frame  1316 / 1830
# printing frame  1317 / 1830
# printing frame  1318 / 1830
# printing frame  1319 / 1830
# printing frame  1320 / 1830
# printing frame  1321 / 1830
# printing frame  1322 / 1830
# printing frame  1323 / 1830
# printing frame  1324 / 1830
# printing frame  1325 / 1830
# printing frame  1326 / 1830
# printing frame  1327 / 1830
# printing frame  1328 / 1830
# printing frame  1329 / 1830
# printing frame  1330 / 1830
# printing frame  1331 / 1830
# printing frame  1332 / 1830
# printing frame  1333 / 1830
# printing frame  1334 / 1830
# printing frame  1335 / 1830
# printing frame  1336 / 1830
# printing frame  1337 / 1830
# printing frame  1338 / 1830
# printing frame  1339 / 1830
# printing frame  1340 / 1830
# printing frame  1341 / 1830
# printing frame  1342 / 1830
# printing frame  1343 / 1830
# printing frame  1344 / 1830
# printing frame  1345 / 1830
# printing frame  1346 / 1830
# printing frame  1347 / 1830
# printing frame  1348 / 1830
# printing frame  1349 / 1830
# printing frame  1350 / 1830
# printing frame  1351 / 1830
# printing frame  1352 / 1830
# printing frame  1353 / 1830
# printing frame  1354 / 1830
# printing frame  1355 / 1830
# printing frame  1356 / 1830
# printing frame  1357 / 1830
# printing frame  1358 / 1830
# printing frame  1359 / 1830
# printing frame  1360 / 1830
# printing frame  1361 / 1830
# printing frame  1362 / 1830
# printing frame  1363 / 1830
# printing frame  1364 / 1830
# printing frame  1365 / 1830
# printing frame  1366 / 1830
# printing frame  1367 / 1830
# printing frame  1368 / 1830
# printing frame  1369 / 1830
# printing frame  1370 / 1830
# printing frame  1371 / 1830
# printing frame  1372 / 1830
# printing frame  1373 / 1830
# printing frame  1374 / 1830
# printing frame  1375 / 1830
# printing frame  1376 / 1830
# printing frame  1377 / 1830
# printing frame  1378 / 1830
# printing frame  1379 / 1830
# printing frame  1380 / 1830
# printing frame  1381 / 1830
# printing frame  1382 / 1830
# printing frame  1383 / 1830
# printing frame  1384 / 1830
# printing frame  1385 / 1830
# printing frame  1386 / 1830
# printing frame  1387 / 1830
# printing frame  1388 / 1830
# printing frame  1389 / 1830
# printing frame  1390 / 1830
# printing frame  1391 / 1830
# printing frame  1392 / 1830
# printing frame  1393 / 1830
# printing frame  1394 / 1830
# printing frame  1395 / 1830
# printing frame  1396 / 1830
# printing frame  1397 / 1830
# printing frame  1398 / 1830
# printing frame  1399 / 1830
# printing frame  1400 / 1830
# printing frame  1401 / 1830
# printing frame  1402 / 1830
# printing frame  1403 / 1830
# printing frame  1404 / 1830
# printing frame  1405 / 1830
# printing frame  1406 / 1830
# printing frame  1407 / 1830
# printing frame  1408 / 1830
# printing frame  1409 / 1830
# printing frame  1410 / 1830
# printing frame  1411 / 1830
# printing frame  1412 / 1830
# printing frame  1413 / 1830
# printing frame  1414 / 1830
# printing frame  1415 / 1830
# printing frame  1416 / 1830
# printing frame  1417 / 1830
# printing frame  1418 / 1830
# printing frame  1419 / 1830
# printing frame  1420 / 1830
# printing frame  1421 / 1830
# printing frame  1422 / 1830
# printing frame  1423 / 1830
# printing frame  1424 / 1830
# printing frame  1425 / 1830
# printing frame  1426 / 1830
# printing frame  1427 / 1830
# printing frame  1428 / 1830
# printing frame  1429 / 1830
# printing frame  1430 / 1830
# printing frame  1431 / 1830
# printing frame  1432 / 1830
# printing frame  1433 / 1830
# printing frame  1434 / 1830
# printing frame  1435 / 1830
# printing frame  1436 / 1830
# printing frame  1437 / 1830
# printing frame  1438 / 1830
# printing frame  1439 / 1830
# printing frame  1440 / 1830
# printing frame  1441 / 1830
# printing frame  1442 / 1830
# printing frame  1443 / 1830
# printing frame  1444 / 1830
# printing frame  1445 / 1830
# printing frame  1446 / 1830
# printing frame  1447 / 1830
# printing frame  1448 / 1830
# printing frame  1449 / 1830
# printing frame  1450 / 1830
# printing frame  1451 / 1830
# printing frame  1452 / 1830
# printing frame  1453 / 1830
# printing frame  1454 / 1830
# printing frame  1455 / 1830
# printing frame  1456 / 1830
# printing frame  1457 / 1830
# printing frame  1458 / 1830
# printing frame  1459 / 1830
# printing frame  1460 / 1830
# printing frame  1461 / 1830
# printing frame  1462 / 1830
# printing frame  1463 / 1830
# printing frame  1464 / 1830
# printing frame  1465 / 1830
# printing frame  1466 / 1830
# printing frame  1467 / 1830
# printing frame  1468 / 1830
# printing frame  1469 / 1830
# printing frame  1470 / 1830
# printing frame  1471 / 1830
# printing frame  1472 / 1830
# printing frame  1473 / 1830
# printing frame  1474 / 1830
# printing frame  1475 / 1830
# printing frame  1476 / 1830
# printing frame  1477 / 1830
# printing frame  1478 / 1830
# printing frame  1479 / 1830
# printing frame  1480 / 1830
# printing frame  1481 / 1830
# printing frame  1482 / 1830
# printing frame  1483 / 1830
# printing frame  1484 / 1830
# printing frame  1485 / 1830
# printing frame  1486 / 1830
# printing frame  1487 / 1830
# printing frame  1488 / 1830
# printing frame  1489 / 1830
# printing frame  1490 / 1830
# printing frame  1491 / 1830
# printing frame  1492 / 1830
# printing frame  1493 / 1830
# printing frame  1494 / 1830
# printing frame  1495 / 1830
# printing frame  1496 / 1830
# printing frame  1497 / 1830
# printing frame  1498 / 1830
# printing frame  1499 / 1830
# printing frame  1500 / 1830
# printing frame  1501 / 1830
# printing frame  1502 / 1830
# printing frame  1503 / 1830
# printing frame  1504 / 1830
# printing frame  1505 / 1830
# printing frame  1506 / 1830
# printing frame  1507 / 1830
# printing frame  1508 / 1830
# printing frame  1509 / 1830
# printing frame  1510 / 1830
# printing frame  1511 / 1830
# printing frame  1512 / 1830
# printing frame  1513 / 1830
# printing frame  1514 / 1830
# printing frame  1515 / 1830
# printing frame  1516 / 1830
# printing frame  1517 / 1830
# printing frame  1518 / 1830
# printing frame  1519 / 1830
# printing frame  1520 / 1830
# printing frame  1521 / 1830
# printing frame  1522 / 1830
# printing frame  1523 / 1830
# printing frame  1524 / 1830
# printing frame  1525 / 1830
# printing frame  1526 / 1830
# printing frame  1527 / 1830
# printing frame  1528 / 1830
# printing frame  1529 / 1830
# printing frame  1530 / 1830
# printing frame  1531 / 1830
# printing frame  1532 / 1830
# printing frame  1533 / 1830
# printing frame  1534 / 1830
# printing frame  1535 / 1830
# printing frame  1536 / 1830
# printing frame  1537 / 1830
# printing frame  1538 / 1830
# printing frame  1539 / 1830
# printing frame  1540 / 1830
# printing frame  1541 / 1830
# printing frame  1542 / 1830
# printing frame  1543 / 1830
# printing frame  1544 / 1830
# printing frame  1545 / 1830
# printing frame  1546 / 1830
# printing frame  1547 / 1830
# printing frame  1548 / 1830
# printing frame  1549 / 1830
# printing frame  1550 / 1830
# printing frame  1551 / 1830
# printing frame  1552 / 1830
# printing frame  1553 / 1830
# printing frame  1554 / 1830
# printing frame  1555 / 1830
# printing frame  1556 / 1830
# printing frame  1557 / 1830
# printing frame  1558 / 1830
# printing frame  1559 / 1830
# printing frame  1560 / 1830
# printing frame  1561 / 1830
# printing frame  1562 / 1830
# printing frame  1563 / 1830
# printing frame  1564 / 1830
# printing frame  1565 / 1830
# printing frame  1566 / 1830
# printing frame  1567 / 1830
# printing frame  1568 / 1830
# printing frame  1569 / 1830
# printing frame  1570 / 1830
# printing frame  1571 / 1830
# printing frame  1572 / 1830
# printing frame  1573 / 1830
# printing frame  1574 / 1830
# printing frame  1575 / 1830
# printing frame  1576 / 1830
# printing frame  1577 / 1830
# printing frame  1578 / 1830
# printing frame  1579 / 1830
# printing frame  1580 / 1830
# printing frame  1581 / 1830
# printing frame  1582 / 1830
# printing frame  1583 / 1830
# printing frame  1584 / 1830
# printing frame  1585 / 1830
# printing frame  1586 / 1830
# printing frame  1587 / 1830
# printing frame  1588 / 1830
# printing frame  1589 / 1830
# printing frame  1590 / 1830
# printing frame  1591 / 1830
# printing frame  1592 / 1830
# printing frame  1593 / 1830
# printing frame  1594 / 1830
# printing frame  1595 / 1830
# printing frame  1596 / 1830
# printing frame  1597 / 1830
# printing frame  1598 / 1830
# printing frame  1599 / 1830
# printing frame  1600 / 1830
# printing frame  1601 / 1830
# printing frame  1602 / 1830
# printing frame  1603 / 1830
# printing frame  1604 / 1830
# printing frame  1605 / 1830
# printing frame  1606 / 1830
# printing frame  1607 / 1830
# printing frame  1608 / 1830
# printing frame  1609 / 1830
# printing frame  1610 / 1830
# printing frame  1611 / 1830
# printing frame  1612 / 1830
# printing frame  1613 / 1830
# printing frame  1614 / 1830
# printing frame  1615 / 1830
# printing frame  1616 / 1830
# printing frame  1617 / 1830
# printing frame  1618 / 1830
# printing frame  1619 / 1830
# printing frame  1620 / 1830
# printing frame  1621 / 1830
# printing frame  1622 / 1830
# printing frame  1623 / 1830
# printing frame  1624 / 1830
# printing frame  1625 / 1830
# printing frame  1626 / 1830
# printing frame  1627 / 1830
# printing frame  1628 / 1830
# printing frame  1629 / 1830
# printing frame  1630 / 1830
# printing frame  1631 / 1830
# printing frame  1632 / 1830
# printing frame  1633 / 1830
# printing frame  1634 / 1830
# printing frame  1635 / 1830
# printing frame  1636 / 1830
# printing frame  1637 / 1830
# printing frame  1638 / 1830
# printing frame  1639 / 1830
# printing frame  1640 / 1830
# printing frame  1641 / 1830
# printing frame  1642 / 1830
# printing frame  1643 / 1830
# printing frame  1644 / 1830
# printing frame  1645 / 1830
# printing frame  1646 / 1830
# printing frame  1647 / 1830
# printing frame  1648 / 1830
# printing frame  1649 / 1830
# printing frame  1650 / 1830
# printing frame  1651 / 1830
# printing frame  1652 / 1830
# printing frame  1653 / 1830
# printing frame  1654 / 1830
# printing frame  1655 / 1830
# printing frame  1656 / 1830
# printing frame  1657 / 1830
# printing frame  1658 / 1830
# printing frame  1659 / 1830
# printing frame  1660 / 1830
# printing frame  1661 / 1830
# printing frame  1662 / 1830
# printing frame  1663 / 1830
# printing frame  1664 / 1830
# printing frame  1665 / 1830
# printing frame  1666 / 1830
# printing frame  1667 / 1830
# printing frame  1668 / 1830
# printing frame  1669 / 1830
# printing frame  1670 / 1830
# printing frame  1671 / 1830
# printing frame  1672 / 1830
# printing frame  1673 / 1830
# printing frame  1674 / 1830
# printing frame  1675 / 1830
# printing frame  1676 / 1830
# printing frame  1677 / 1830
# printing frame  1678 / 1830
# printing frame  1679 / 1830
# printing frame  1680 / 1830
# printing frame  1681 / 1830
# printing frame  1682 / 1830
# printing frame  1683 / 1830
# printing frame  1684 / 1830
# printing frame  1685 / 1830
# printing frame  1686 / 1830
# printing frame  1687 / 1830
# printing frame  1688 / 1830
# printing frame  1689 / 1830
# printing frame  1690 / 1830
# printing frame  1691 / 1830
# printing frame  1692 / 1830
# printing frame  1693 / 1830
# printing frame  1694 / 1830
# printing frame  1695 / 1830
# printing frame  1696 / 1830
# printing frame  1697 / 1830
# printing frame  1698 / 1830
# printing frame  1699 / 1830
# printing frame  1700 / 1830
# printing frame  1701 / 1830
# printing frame  1702 / 1830
# printing frame  1703 / 1830
# printing frame  1704 / 1830
# printing frame  1705 / 1830
# printing frame  1706 / 1830
# printing frame  1707 / 1830
# printing frame  1708 / 1830
# printing frame  1709 / 1830
# printing frame  1710 / 1830
# printing frame  1711 / 1830
# printing frame  1712 / 1830
# printing frame  1713 / 1830
# printing frame  1714 / 1830
# printing frame  1715 / 1830
# printing frame  1716 / 1830
# printing frame  1717 / 1830
# printing frame  1718 / 1830
# printing frame  1719 / 1830
# printing frame  1720 / 1830
# printing frame  1721 / 1830
# printing frame  1722 / 1830
# printing frame  1723 / 1830
# printing frame  1724 / 1830
# printing frame  1725 / 1830
# printing frame  1726 / 1830
# printing frame  1727 / 1830
# printing frame  1728 / 1830
# printing frame  1729 / 1830
# printing frame  1730 / 1830
# printing frame  1731 / 1830
# printing frame  1732 / 1830
# printing frame  1733 / 1830
# printing frame  1734 / 1830
# printing frame  1735 / 1830
# printing frame  1736 / 1830
# printing frame  1737 / 1830
# printing frame  1738 / 1830
# printing frame  1739 / 1830
# printing frame  1740 / 1830
# printing frame  1741 / 1830
# printing frame  1742 / 1830
# printing frame  1743 / 1830
# printing frame  1744 / 1830
# printing frame  1745 / 1830
# printing frame  1746 / 1830
# printing frame  1747 / 1830
# printing frame  1748 / 1830
# printing frame  1749 / 1830
# printing frame  1750 / 1830
# printing frame  1751 / 1830
# printing frame  1752 / 1830
# printing frame  1753 / 1830
# printing frame  1754 / 1830
# printing frame  1755 / 1830
# printing frame  1756 / 1830
# printing frame  1757 / 1830
# printing frame  1758 / 1830
# printing frame  1759 / 1830
# printing frame  1760 / 1830
# printing frame  1761 / 1830
# printing frame  1762 / 1830
# printing frame  1763 / 1830
# printing frame  1764 / 1830
# printing frame  1765 / 1830
# printing frame  1766 / 1830
# printing frame  1767 / 1830
# printing frame  1768 / 1830
# printing frame  1769 / 1830
# printing frame  1770 / 1830
# printing frame  1771 / 1830
# printing frame  1772 / 1830
# printing frame  1773 / 1830
# printing frame  1774 / 1830
# printing frame  1775 / 1830
# printing frame  1776 / 1830
# printing frame  1777 / 1830
# printing frame  1778 / 1830
# printing frame  1779 / 1830
# printing frame  1780 / 1830
# printing frame  1781 / 1830
# printing frame  1782 / 1830
# printing frame  1783 / 1830
# printing frame  1784 / 1830
# printing frame  1785 / 1830
# printing frame  1786 / 1830
# printing frame  1787 / 1830
# printing frame  1788 / 1830
# printing frame  1789 / 1830
# printing frame  1790 / 1830
# printing frame  1791 / 1830
# printing frame  1792 / 1830
# printing frame  1793 / 1830
# printing frame  1794 / 1830
# printing frame  1795 / 1830
# printing frame  1796 / 1830
# printing frame  1797 / 1830
# printing frame  1798 / 1830
# printing frame  1799 / 1830
# printing frame  1800 / 1830
# printing frame  1801 / 1830
# printing frame  1802 / 1830
# printing frame  1803 / 1830
# printing frame  1804 / 1830
# printing frame  1805 / 1830
# printing frame  1806 / 1830
# printing frame  1807 / 1830
# printing frame  1808 / 1830
# printing frame  1809 / 1830
# printing frame  1810 / 1830
# printing frame  1811 / 1830
# printing frame  1812 / 1830
# printing frame  1813 / 1830
# printing frame  1814 / 1830
# printing frame  1815 / 1830
# printing frame  1816 / 1830
# printing frame  1817 / 1830
# printing frame  1818 / 1830
# printing frame  1819 / 1830
# printing frame  1820 / 1830
# printing frame  1821 / 1830
# printing frame  1822 / 1830
# printing frame  1823 / 1830
# printing frame  1824 / 1830
# printing frame  1825 / 1830
# printing frame  1826 / 1830
# printing frame  1827 / 1830
# printing frame  1828 / 1830
# printing frame  1829 / 1830
# printing frame  1830 / 1830

# %%
bodyparts_locs_3d = bodyparts_3d_anipose['weikang']

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.gridspec import GridSpec
import scipy
import string
import warnings
import pickle
import cv2
import os   
import matplotlib.animation as animation

import warnings
warnings.filterwarnings("ignore")    

if withboxCorner:
    skeletons = [ ['rightTuft','rightEye'],
                  ['rightTuft','whiteBlaze'],
                  ['leftTuft','leftEye'],
                  ['leftTuft','whiteBlaze'],
                  ['rightEye','whiteBlaze'],
                  ['leftEye','whiteBlaze'],
                  ['rightEye','mouth'],
                  ['leftEye','mouth'],
                  ['leftEye','rightEye'],
                  ['boxCorner1','boxCorner2'],
                  ['boxCorner2','boxCorner3'],
                  ['boxCorner3','boxCorner4']
                ]
else:
    skeletons = [ ['rightTuft','rightEye'],
                  ['rightTuft','whiteBlaze'],
                  ['leftTuft','leftEye'],
                  ['leftTuft','whiteBlaze'],
                  ['rightEye','whiteBlaze'],
                  ['leftEye','whiteBlaze'],
                  ['rightEye','mouth'],
                  ['leftEye','mouth'],
                  ['leftEye','rightEye']
                ]
nskeletons = np.shape(skeletons)[0]

colors = ['b','r','k']


# Settings
clear_frames = True     # Should it clear the figure between each frame?
fps = 30

# Output video writer
FFMpegWriter = animation.writers['ffmpeg']
metadata = dict(title='Animal tracking demo', artist='Matplotlib', comment='')
writer = FFMpegWriter(fps=fps, metadata=metadata)

# animal_names_unique = pd.unique(pd.DataFrame(bodyparts_locs_3d.keys()).iloc[:,0])
# body_parts_unique = pd.unique(pd.DataFrame(bodyparts_locs_3d.keys()).iloc[:,1])
animal_names_unique = animalnames_videotrack
body_parts_unique = bodypartnames_videotrack    

nanimals = np.shape(animal_names_unique)[0]  
nbodyparts = np.shape(body_parts_unique)[0]

for iname in np.arange(0,nanimals,1):
    for ibody in np.arange(0,nbodyparts,1):
        if (iname == 0) & (ibody == 0):
            xxx = np.array(bodyparts_locs_3d[(animal_names_unique[iname],body_parts_unique[ibody])])
        else:
            xxx2 = np.array(bodyparts_locs_3d[(animal_names_unique[iname],body_parts_unique[ibody])])
            xxx = np.concatenate([xxx,xxx2])

# %%
X = xxx[:,0]
Y = xxx[:,1]
Z = xxx[:,2]
old_axis_x = np.array([1, 0, 0])
old_axis_y = np.array([0, 1, 0])
old_axis_z = np.array([0, 0, 1])

new_axis_x = np.array(bodyparts_locs_3d[('dodson','boxCorner3')])[0,:]-np.array(bodyparts_locs_3d[('scorch','boxCorner3')])[0,:]
new_axis_y = np.array(bodyparts_locs_3d[('dodson','boxCorner4')])[0,:]-np.array(bodyparts_locs_3d[('dodson','boxCorner3')])[0,:] 
new_axis_z = np.array(bodyparts_locs_3d[('dodson','boxCorner1')])[0,:]-np.array(bodyparts_locs_3d[('dodson','boxCorner2')])[0,:] 

# rotate angles
angle_x_rad = np.arccos(np.dot(old_axis_x, new_axis_x) / (np.linalg.norm(old_axis_x) * np.linalg.norm(new_axis_x))) 
angle_y_rad = np.arccos(np.dot(old_axis_y, new_axis_y) / (np.linalg.norm(old_axis_y) * np.linalg.norm(new_axis_y))) 
angle_z_rad = -np.arccos(np.dot(old_axis_z, new_axis_z) / (np.linalg.norm(old_axis_z) * np.linalg.norm(new_axis_z)))

# rotate
X_rot = X * np.cos(angle_y_rad) * np.cos(angle_z_rad) + \
        Y * (np.cos(angle_z_rad) * np.sin(angle_x_rad) * np.sin(angle_y_rad) - np.cos(angle_x_rad) * np.sin(angle_z_rad)) + \
        Z * (np.sin(angle_x_rad) * np.sin(angle_z_rad) * np.cos(angle_y_rad) + np.cos(angle_x_rad) * np.sin(angle_y_rad))

Y_rot = X * np.cos(angle_y_rad) * np.sin(angle_z_rad) + \
        Y * (np.cos(angle_x_rad) * np.cos(angle_z_rad) + np.sin(angle_x_rad) * np.sin(angle_y_rad) * np.sin(angle_z_rad)) + \
        Z * (-np.cos(angle_z_rad) * np.sin(angle_x_rad) + np.cos(angle_x_rad) * np.sin(angle_y_rad) * np.sin(angle_z_rad))

Z_rot = -X * np.sin(angle_y_rad) + \
         Y * np.cos(angle_y_rad) * np.sin(angle_x_rad) + \
         Z * np.cos(angle_x_rad) * np.cos(angle_y_rad)

# %%
xyz_min = np.nanmin(xxx,axis=0)
xyz_max = np.nanmax(xxx,axis=0)

# %%
xyz_min
# Out:
# array([-13.17524783,  -9.95422746,   4.86768232])
